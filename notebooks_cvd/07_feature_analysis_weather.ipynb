# %% [markdown]
# # Feature Analysis: Weather Variables
#
# ## Purpose
# This notebook performs comprehensive feature analysis on the **weather/environmental variables** to identify:
# 1. **Redundant features** - highly correlated pairs (|r| > 0.85)
# 2. **Multicollinearity** - VIF values indicating collinear variables
# 3. **Predictive relevance** - correlation with target variable (CVD Mortality Rate)
# 4. **Feature groupings** - hierarchical clustering patterns
#
# ## Goal
# Make informed decisions about which weather features to keep/drop before modeling:
# - **Drop** one variable from highly correlated pairs
# - **Keep** the variable with stronger target correlation and lower VIF
#
# ## Scope
# This notebook analyzes **weather variables only** (after removing irrelevant ones):
# - Start with ~103 weather variables from combined dataset
# - Remove demographics variables (analyzed in notebook 06)
# - Remove livestock variables (8 animal types)
# - Remove 67 known irrelevant weather variables
# - Analyze remaining ~35-40 relevant weather variables
#
# ## Output
# - Visualizations saved to: `data_cvd/outputs/feature_analysis/`
# - Publication-ready plots (high DPI, proper sizing)

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform
from statsmodels.stats.outliers_influence import variance_inflation_factor
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Set plotting style for publication quality
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Print versions for reproducibility
print("Library versions:")
print(f"  pandas: {pd.__version__}")
print(f"  numpy: {np.__version__}")
print(f"  matplotlib: {plt.matplotlib.__version__}")
print(f"  seaborn: {sns.__version__}")
# Out:
# Library versions:
#   pandas: 2.3.3
#   numpy: 1.26.4
#   matplotlib: 3.10.8
#   seaborn: 0.13.2

# %% [markdown]
# ## 2. Setup Output Directory
#
# Use the same output directory as demographics analysis.

# %%
# Use same output directory as notebook 06
output_dir = Path('../data_cvd/outputs/feature_analysis')
output_dir.mkdir(parents=True, exist_ok=True)

print(f" Output directory: {output_dir}")
print(f"  All weather analysis plots will be saved here in high resolution (300 DPI)")
# Out:
#  Output directory: ../data_cvd/outputs/feature_analysis
#   All weather analysis plots will be saved here in high resolution (300 DPI)

# %% [markdown]
# ## 3. Load Data
#
# Load the combined dataset from notebook 05.

# %%
# Load final combined dataset
df = pd.read_csv('../data_cvd/combined_final/final_combined_all_variables.csv')

print("=" * 70)
print("DATASET LOADED")
print("=" * 70)
print(f"Shape: {df.shape}")
print(f"  - Rows: {df.shape[0]:,}")
print(f"  - Columns: {df.shape[1]}")
print(f"  - Years: {sorted(df['Year'].unique())}")
# Out:
# ======================================================================
# DATASET LOADED
# ======================================================================
# Shape: (24487, 132)
#   - Rows: 24,487
#   - Columns: 132
#   - Years: [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %% [markdown]
# ## 4. Define Variables to Exclude
#
# ### 4.1 Demographics Variables
#
# These were analyzed in notebook 06 and should be excluded from weather analysis.

# %%
# Define demographics variables to exclude (same as notebook 06)
demographics_cols = [
    # Original ACS variables
    'Median Household Income',
    'Total Population',
    'Gini Index',
    'Median Age',
    'Poverty Rate',
    'Unemployment Rate',
    'Disability Rate',
    "Bachelor's Degree or Higher (%)",
    "High School Degree or Higher (%)",
    # Engineered percentage features
    'White Population (%)',
    'Hispanic Population (%)',
    'Black Population (%)',
    'Households with No Vehicle (%)',
    'Rent Burden (+50% of HI)',
    'Single Mother Families (%)'
]

# Filter to only columns that exist
demographics_cols = [col for col in demographics_cols if col in df.columns]

print(f"Demographics variables to exclude: {len(demographics_cols)}")
# Out:
# Demographics variables to exclude: 15

# %% [markdown]
# ### 4.2 Livestock Variables
#
# These will be analyzed separately if needed.

# %%
# Define livestock variables to exclude
livestock_cols = [
    'Buffalo', 'Cattle', 'Chicken', 'Duck', 
    'Goat', 'Horse', 'Pig', 'Sheep'
]

# Filter to only columns that exist
livestock_cols = [col for col in livestock_cols if col in df.columns]

print(f"Livestock variables to exclude: {len(livestock_cols)}")
# Out:
# Livestock variables to exclude: 8

# %% [markdown]
# ### 4.3 Irrelevant Weather Variables
#
# These 67 weather variables are known to be redundant or irrelevant and should be dropped before analysis.

# %%
# Define irrelevant weather variables to exclude (from user's list)
irrelevant_weather_cols = [
    'PM$_{10}$',
    'FoT PM$_{10}$ above EPA threshold', 
    'FoT PM$_{10}$ above75ᵗʰ percentile',
    'FoT PM$_{1}$ above75ᵗʰ percentile', 
    'PM$_1$', 
    'Specific humidity.1', 
    'Total column water',
    '2m dew point temperature', 
    '2m temperature',
    'PM$_{2.5}$', 
    'FoT Temperature above 90 $\\mathrm{^o F}$', 
    'FoT Temperature below 0 $\\mathrm{^o C}$',
    'FoT PM$_{2.5}$ above EPA threshold', 
    'Temperature', 
    'Surface geopotential',
    'Dust aerosol (0.03-0.55 µm) mixing ratio', 
    'Nitrogen dioxide', 
    'Peroxyacetyl nitrate', 
    'Formaldehyde',
    'Sulphur dioxide', 
    'Nitric acid', 
    'Propane',
    'Nitrogen monoxide',
    'Ozone', 
    'Hydrogen peroxide', 
    'Specific humidity',
    
    # Total AOD measurements (redundant aerosol measurements)
    'Total AOD at 469 nm', 
    'Total AOD at 550 nm', 
    'Total AOD at 670 nm', 
    'Total AOD at 865 nm',
    'Total AOD at 1240 nm',
    
    # Total column gas measurements (redundant with other air quality measures)
    'Total column carbon monoxide', 
    'Total column ethane', 
    'Total column formaldehyde',
    'Total column hydrogen peroxide', 
    'Total column hydroxyl radical', 
    'Total column isoprene', 
    'Total column methane', 
    'Total column nitric acid', 
    'Total column nitrogen dioxide', 
    'Total column ozone', 
    'Total column peroxyacetyl nitrate',
    'Total column propane', 
    'Total column sulphur dioxide', 
    'Total column water vapour',
    'Total column nitrogen monoxide',
    
    # Vertically integrated aerosol masses (redundant)
    'Vertically integrated mass of dust aerosol (0.03-0.55 µm)',
    'Vertically integrated mass of dust aerosol (0.55-9 µm)', 
    'Vertically integrated mass of dust aerosol (9-20 µm)',
    'Vertically integrated mass of hydrophilic black carbon aerosol', 
    'Vertically integrated mass of hydrophilic organic matter aerosol',
    'Vertically integrated mass of hydrophobic organic matter aerosol',
    'Vertically integrated mass of hydrophobic black carbon aerosol', 
    'Vertically integrated mass of sea salt aerosol (0.03-0.5 µm)',
    'Vertically integrated mass of sea salt aerosol (0.5-5 µm)', 
    'Vertically integrated mass of sea salt aerosol (5-20 µm)',
    'Vertically integrated mass of sulphate aerosol', 
    'Vertically integrated mass of sulphur dioxide'
]

# Filter to only columns that exist
irrelevant_weather_cols = [col for col in irrelevant_weather_cols if col in df.columns]

print(f"Irrelevant weather variables to exclude: {len(irrelevant_weather_cols)}")
print("\nCategories:")
pm_vars = [col for col in irrelevant_weather_cols if 'PM' in col]
temp_vars = [col for col in irrelevant_weather_cols if 'temperature' in col.lower() or 'Temperature' in col]
aod_vars = [col for col in irrelevant_weather_cols if 'AOD' in col]
total_column_vars = [col for col in irrelevant_weather_cols if 'Total column' in col]
vertically_vars = [col for col in irrelevant_weather_cols if 'Vertically integrated' in col]
other_vars = [col for col in irrelevant_weather_cols if col not in pm_vars + temp_vars + aod_vars + total_column_vars + vertically_vars]

print(f"  - PM variables: {len(pm_vars)}")
print(f"  - Temperature variables: {len(temp_vars)}")
print(f"  - AOD measurements: {len(aod_vars)}")
print(f"  - Total column gases: {len(total_column_vars)}")
print(f"  - Vertically integrated masses: {len(vertically_vars)}")
print(f"  - Other: {len(other_vars)}")
# Out:
# Irrelevant weather variables to exclude: 58
#
# Categories:
#   - PM variables: 7
#   - Temperature variables: 5
#   - AOD measurements: 5
#   - Total column gases: 16
#   - Vertically integrated masses: 12
#   - Other: 13

# %% [markdown]
# ### 4.4 Identifiers and Target Variable

# %%
# Define identifiers and target to exclude
identifiers = ['County', 'State', 'Year', 'fips']
target = ['CVD Mortality Rate']

# Filter to only columns that exist
identifiers = [col for col in identifiers if col in df.columns]
target = [col for col in target if col in df.columns]

print(f"Identifiers to exclude: {len(identifiers)}")
print(f"Target variable: {target}")
# Out:
# Identifiers to exclude: 4
# Target variable: ['CVD Mortality Rate']

# %% [markdown]
# ## 5. Extract Weather Variables
#
# Identify weather variables by excluding all non-weather columns.

# %%
print("=" * 70)
print("EXTRACTING WEATHER VARIABLES")
print("=" * 70)

# Combine all columns to exclude
exclude_cols = identifiers + target + demographics_cols + livestock_cols + irrelevant_weather_cols

print(f"\nTotal columns to exclude: {len(exclude_cols)}")
print(f"  - Identifiers: {len(identifiers)}")
print(f"  - Target: {len(target)}")
print(f"  - Demographics: {len(demographics_cols)}")
print(f"  - Livestock: {len(livestock_cols)}")
print(f"  - Irrelevant weather: {len(irrelevant_weather_cols)}")

# Extract weather variables (all columns except those to exclude)
weather_cols = [col for col in df.columns if col not in exclude_cols]

print(f"\n Relevant weather variables identified: {len(weather_cols)}")

# Create weather subset
weather_df = df[weather_cols + ['CVD Mortality Rate']].copy()

print(f"\nWeather subset shape: {weather_df.shape}")
print(f"  - Rows: {weather_df.shape[0]:,}")
print(f"  - Weather features: {len(weather_cols)}")
print(f"  - Target variable: 1 (CVD Mortality Rate)")
# Out:
# ======================================================================
# EXTRACTING WEATHER VARIABLES
# ======================================================================
#
# Total columns to exclude: 86
#   - Identifiers: 4
#   - Target: 1
#   - Demographics: 15
#   - Livestock: 8
#   - Irrelevant weather: 58
#
#  Relevant weather variables identified: 46
#
# Weather subset shape: (24487, 47)
#   - Rows: 24,487
#   - Weather features: 46
#   - Target variable: 1 (CVD Mortality Rate)

# %% [markdown]
# ## 6. List Weather Variables
#
# Display all weather variables that will be analyzed.

# %%
print("=" * 70)
print(f"WEATHER VARIABLES TO ANALYZE ({len(weather_cols)})")
print("=" * 70)
print("\nVariables:")
for i, col in enumerate(sorted(weather_cols), 1):
    print(f"  {i:2}. {col}")
# Out:
# ======================================================================
# WEATHER VARIABLES TO ANALYZE (46)
# ======================================================================
#
# Variables:
#    1. 10m wind speed
#    2. Black carbon AOD at 550 nm
#    3. Carbon monoxide
#    4. Dust AOD at 550 nm
#    5. Dust aerosol (0.55-0.9 µm) mixing ratio
#    6. Dust aerosol (0.9-20 µm) mixing ratio
#    7. Ethane
#    8. Fips
#    9. FoT Carbonmonoxide above75ᵗʰ percentile
#   10. FoT Ethane above75ᵗʰ percentile
#   11. FoT Formaldehyde above75ᵗʰ percentile
#   12. FoT Hydrogen peroxide above75ᵗʰ percentile
#   13. FoT Hydroxyl radical above75ᵗʰ percentile
#   14. FoT Isoprene above75ᵗʰ percentile
#   15. FoT Nitric acid above75ᵗʰ percentile
#   16. FoT Nitrogen dioxide above75ᵗʰ percentile
#   17. FoT Nitrogen monoxide above75ᵗʰ percentile
#   18. FoT Ozone above75ᵗʰ percentile
#   19. FoT PM$_{2.5}$ above75ᵗʰ percentile
#   20. FoT Peroxyacetyl Nitrate above75ᵗʰ percentile
#   21. FoT Propane above75ᵗʰ percentile
#   22. FoT Sulphur dioxide above75ᵗʰ percentile
#   23. FoT Temperature above75ᵗʰ percentile
#   24. FoT Temperature below25ᵗʰ percentile
#   25. Hydrophilic black carbon aerosol mixing ratio
#   26. Hydrophilic organic matter aerosol mixing ratio
#   27. Hydrophobic black carbon aerosol mixing ratio
#   28. Hydrophobic organic matter aerosol mixing ratio
#   29. Hydroxyl radical
#   30. Isoprene
#   31. Land-sea mask
#   32. Leaf area index, high vegetation
#   33. Leaf area index, low vegetation
#   34. Mean sea level pressure
#   35. Organic matter AOD at 550 nm
#   36. Relative humidity
#   37. Sea salt AOD at 550 nm
#   38. Sea salt aerosol (0.03-0.5 µm) mixing ratio
#   39. Sea salt aerosol (0.5-5 µm) mixing ratio
#   40. Sea salt aerosol (5-20 µm) mixing ratio
#   41. Snow albedo
#   42. Snow depth
#   43. Sulphate AOD at 550 nm
#   44. Sulphate aerosol mixing ratio
#   45. Surface pressure
#   46. Wet bulb temperature

# %% [markdown]
# ## 7. Descriptive Statistics
#
# Overview of weather variables: distributions, ranges, missing values.

# %%
print("=" * 70)
print("DESCRIPTIVE STATISTICS")
print("=" * 70)

# Check for missing values
missing = weather_df.isnull().sum()
if missing.sum() > 0:
    print("\n Missing values detected:")
    for col in missing[missing > 0].index:
        print(f"  {col}: {missing[col]:,} ({missing[col]/len(weather_df)*100:.2f}%)")
else:
    print("\n No missing values")

# Summary statistics
print("\nSummary statistics:")
weather_df.describe()
# Out:
# ======================================================================
# DESCRIPTIVE STATISTICS
# ======================================================================
#
#  No missing values
#
# Summary statistics:
#                Fips  Black carbon AOD at 550 nm  Dust AOD at 550 nm  \
# count  24487.000000                24487.000000        24487.000000
# mean   30552.545963                    0.006957            0.006823
# std    14977.518684                    0.001643            0.004220
# min     1001.000000                    0.002853            0.000965
# 25%    19031.000000                    0.005912            0.003684
# 50%    29173.000000                    0.006670            0.005818
# 75%    45077.000000                    0.007674            0.008871
# max    56045.000000                    0.020297            0.030306
#
#        Land-sea mask  Mean sea level pressure  Organic matter AOD at 550 nm  \
# count   24487.000000             24487.000000                  24487.000000
# mean        0.940175            101717.215378                      0.074638
# std         0.117245               112.263376                      0.013602
# min         0.134455            101190.734156                      0.025448
# 25%         0.962231            101640.656337                      0.067629
# 50%         0.984592            101728.993033                      0.075164
# 75%         0.993097            101800.802399                      0.083752
# max         0.999933            102016.076978                      0.119383
#
#        Sea salt AOD at 550 nm  Sulphate AOD at 550 nm  Surface pressure  \
# count            24487.000000            24487.000000      24487.000000
# mean                 0.007459                0.050543      96732.896935
# std                  0.004336                0.015252       5275.659436
# min                  0.002506                0.016799      71376.504085
# 25%                  0.004796                0.037099      96184.613921
# 50%                  0.005836                0.053757      98358.289992
# 75%                  0.008669                0.062913      99859.437344
# max                  0.046040                0.107583     101854.756871
#
#        Carbon monoxide  ...  FoT Nitrogen dioxide above75ᵗʰ percentile  \
# count     2.448700e+04  ...                               24487.000000
# mean      1.630836e-07  ...                                  27.023090
# std       2.044880e-08  ...                                  14.714983
# min       9.749192e-08  ...                                   0.223881
# 25%       1.517833e-07  ...                                  15.479452
# 50%       1.636864e-07  ...                                  25.785519
# 75%       1.730789e-07  ...                                  37.910448
# max       6.502018e-07  ...                                  86.407104
#
#        FoT Nitrogen monoxide above75ᵗʰ percentile  \
# count                                24487.000000
# mean                                    15.376378
# std                                      9.153050
# min                                      0.717213
# 25%                                      8.915922
# 50%                                     13.732877
# 75%                                     19.535519
# max                                     76.061644
#
#        FoT Ozone above75ᵗʰ percentile  \
# count                    24487.000000
# mean                        43.344840
# std                          6.302588
# min                         19.774590
# 25%                         39.452055
# 50%                         43.731343
# 75%                         47.157534
# max                         88.424658
#
#        FoT Hydrogen peroxide above75ᵗʰ percentile  \
# count                                24487.000000
# mean                                    25.527466
# std                                      9.318040
# min                                      0.239071
# 25%                                     18.458904
# 50%                                     24.417808
# 75%                                     31.830601
# max                                     79.212329
#
#        FoT PM$_{2.5}$ above75ᵗʰ percentile  FoT Propane above75ᵗʰ percentile  \
# count                         24487.000000                      24487.000000
# mean                             34.349782                         26.494420
# std                              10.506852                         19.200888
# min                               3.219178                          0.000000
# 25%                              27.306548                         11.815068
# 50%                              36.369863                         22.438525
# 75%                              42.020548                         40.684932
# max                              76.161202                         98.664384
#
#        FoT Sulphur dioxide above75ᵗʰ percentile  \
# count                              24487.000000
# mean                                  23.346542
# std                                   23.766495
# min                                    0.000000
# 25%                                    0.922131
# 50%                                   15.932836
# 75%                                   40.582192
# max                                   96.815068
#
#        FoT Temperature above75ᵗʰ percentile  \
# count                          24487.000000
# mean                              43.663401
# std                               15.496757
# min                                1.980874
# 25%                               32.864163
# 50%                               42.739726
# 75%                               53.512611
# max                               99.280822
#
#        FoT Temperature below25ᵗʰ percentile  CVD Mortality Rate
# count                          24487.000000        24487.000000
# mean                              36.309714            0.002709
# std                               15.786625            0.000549
# min                                0.000000            0.000731
# 25%                               24.212329            0.002310
# 50%                               37.739726            0.002653
# 75%                               48.664384            0.003059
# max                               79.781421            0.006389
#
# [8 rows x 47 columns]

# %% [markdown]
# ## 8. Inter-Feature Correlation Analysis
#
# ### 8.1 Correlation Matrix Heatmap (Without Annotations)
#
# With 35-40 variables, annotations would be too cluttered. Show color patterns only.

# %%
# Calculate correlation matrix (exclude target variable for now)
corr_matrix = weather_df[weather_cols].corr()

# Create publication-quality heatmap WITHOUT annotations
fig, ax = plt.subplots(figsize=(16, 14))

# Create heatmap WITHOUT annotations (too many variables)
sns.heatmap(corr_matrix, 
            annot=False,  # No annotations - would be too cluttered
            cmap='coolwarm',  # Diverging colormap
            center=0,    # Center colormap at 0
            vmin=-1, vmax=1,  # Fix scale
            square=True,  # Square cells
            linewidths=0,  # No grid lines (too cluttered)
            cbar_kws={'label': 'Pearson Correlation', 'shrink': 0.8},
            ax=ax)

plt.title('Weather Variables: Correlation Matrix', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Variables', fontsize=12, fontweight='bold')
plt.ylabel('Variables', fontsize=12, fontweight='bold')
plt.xticks(rotation=90, ha='right', fontsize=7)
plt.yticks(rotation=0, fontsize=7)
plt.tight_layout()

# Save high-resolution figure
plt.savefig(output_dir / 'weather_correlation_matrix.png', 
            dpi=300, bbox_inches='tight')
print(" Saved: weather_correlation_matrix.png")
plt.show()

print("\nNote: Due to the large number of variables, the heatmap shows color patterns only.")
print("      See the high correlation pairs table below for specific values.")
# Out:
#  Saved: weather_correlation_matrix.png
# Note: Due to the large number of variables, the heatmap shows color patterns only.
#       See the high correlation pairs table below for specific values.

# %% [markdown]
# ### 8.2 High Correlation Pairs
#
# Identify variable pairs with |correlation| > 0.85 (indicating potential redundancy).

# %%
print("=" * 70)
print("HIGH CORRELATION PAIRS (|r| > 0.85)")
print("=" * 70)

# Find high correlation pairs
threshold = 0.85
high_corr_pairs = []

# Iterate through correlation matrix
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            high_corr_pairs.append({
                'Variable 1': corr_matrix.columns[i],
                'Variable 2': corr_matrix.columns[j],
                'Correlation': corr_matrix.iloc[i, j]
            })

if high_corr_pairs:
    high_corr_df = pd.DataFrame(high_corr_pairs)
    high_corr_df = high_corr_df.sort_values('Correlation', key=abs, ascending=False)
    
    print(f"\nFound {len(high_corr_df)} pairs with |correlation| > {threshold}:")
    print("\n" + high_corr_df.to_string(index=False))
    
    # Save to CSV
    high_corr_df.to_csv(output_dir / 'weather_high_correlation_pairs.csv', index=False)
    print(f"\n Saved: weather_high_correlation_pairs.csv")
else:
    print(f"\n No variable pairs with |correlation| > {threshold}")
# Out:
# ======================================================================
# HIGH CORRELATION PAIRS (|r| > 0.85)
# ======================================================================
#
# Found 26 pairs with |correlation| > 0.85:
#
#                                      Variable 1                                      Variable 2  Correlation
#     Sea salt aerosol (0.03-0.5 µm) mixing ratio        Sea salt aerosol (0.5-5 µm) mixing ratio     0.999637
#                            Wet bulb temperature            FoT Temperature below25ᵗʰ percentile    -0.967276
#            FoT Temperature above75ᵗʰ percentile            FoT Temperature below25ᵗʰ percentile    -0.954340
#                                        Isoprene               FoT Isoprene above75ᵗʰ percentile     0.943242
#        Sea salt aerosol (0.5-5 µm) mixing ratio         Sea salt aerosol (5-20 µm) mixing ratio     0.937121
#           FoT Formaldehyde above75ᵗʰ percentile               FoT Isoprene above75ᵗʰ percentile     0.934695
#                            Wet bulb temperature            FoT Temperature above75ᵗʰ percentile     0.933475
#     Sea salt aerosol (0.03-0.5 µm) mixing ratio         Sea salt aerosol (5-20 µm) mixing ratio     0.931441
#      FoT Hydrogen peroxide above75ᵗʰ percentile            FoT Temperature above75ᵗʰ percentile     0.930523
# Hydrophilic organic matter aerosol mixing ratio Hydrophobic organic matter aerosol mixing ratio     0.929871
#           FoT Formaldehyde above75ᵗʰ percentile   FoT Peroxyacetyl Nitrate above75ᵗʰ percentile     0.919376
#                              Dust AOD at 550 nm         Dust aerosol (0.55-0.9 µm) mixing ratio     0.915164
#                                Hydroxyl radical       FoT Hydroxyl radical above75ᵗʰ percentile     0.893019
#                          Sea salt AOD at 550 nm     Sea salt aerosol (0.03-0.5 µm) mixing ratio     0.885840
#                                          Ethane Hydrophobic organic matter aerosol mixing ratio     0.885626
#                          Sea salt AOD at 550 nm        Sea salt aerosol (0.5-5 µm) mixing ratio     0.881203
#                                          Ethane   Hydrophobic black carbon aerosol mixing ratio     0.880629
#                 FoT Ethane above75ᵗʰ percentile                FoT Propane above75ᵗʰ percentile     0.876953
#      FoT Hydrogen peroxide above75ᵗʰ percentile            FoT Temperature below25ᵗʰ percentile    -0.873181
#                              Dust AOD at 550 nm      FoT Hydrogen peroxide above75ᵗʰ percentile     0.869537
#                                        Isoprene           FoT Formaldehyde above75ᵗʰ percentile     0.867614
#                          Sulphate AOD at 550 nm                   Sulphate aerosol mixing ratio     0.865650
#                                 Carbon monoxide                                          Ethane     0.863193
#                                 Carbon monoxide Hydrophobic organic matter aerosol mixing ratio     0.857356
#   Hydrophobic black carbon aerosol mixing ratio Hydrophobic organic matter aerosol mixing ratio     0.856058
#                            Wet bulb temperature      FoT Hydrogen peroxide above75ᵗʰ percentile     0.853367
#
#  Saved: weather_high_correlation_pairs.csv

# %% [markdown]
# ### 8.3 Hierarchical Clustering Dendrogram
#
# Visualize natural groupings of correlated weather variables using hierarchical clustering.

# %%
# Calculate distance matrix from correlations
# Distance = 1 - |correlation|
distance_matrix = 1 - np.abs(corr_matrix)

# Perform hierarchical clustering
linkage_matrix = linkage(squareform(distance_matrix), method='average')

# Create publication-quality dendrogram
fig, ax = plt.subplots(figsize=(18, 10))

dendrogram(linkage_matrix, 
           labels=corr_matrix.columns,
           orientation='top',
           distance_sort='ascending',
           show_leaf_counts=False,
           leaf_font_size=8,
           ax=ax)

plt.title('Weather Variables: Hierarchical Clustering Dendrogram', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Variables', fontsize=12, fontweight='bold')
plt.ylabel('Distance (1 - |Correlation|)', fontsize=12, fontweight='bold')
plt.xticks(rotation=90, ha='right')

# Add horizontal line at threshold
threshold_distance = 1 - threshold
plt.axhline(y=threshold_distance, color='r', linestyle='--', 
            linewidth=2, label=f'Threshold (|r| = {threshold})')
plt.legend(loc='upper right', fontsize=10)

plt.tight_layout()

# Save high-resolution figure
plt.savefig(output_dir / 'weather_dendrogram.png', 
            dpi=300, bbox_inches='tight')
print(" Saved: weather_dendrogram.png")
plt.show()

print("\nInterpretation:")
print("  - Variables connected below the red line (threshold) are highly correlated")
print("  - Consider keeping only one representative from each tight cluster")
# Out:
#  Saved: weather_dendrogram.png
# Interpretation:
#   - Variables connected below the red line (threshold) are highly correlated
#   - Consider keeping only one representative from each tight cluster

# %% [markdown]
# ## 9. Relationship with Target Variable
#
# ### 9.1 Feature-Target Correlation
#
# Calculate correlation of each weather feature with CVD Mortality Rate.

# %%
# Calculate correlation with target variable
target_corr = weather_df[weather_cols].corrwith(weather_df['CVD Mortality Rate'])
target_corr = target_corr.sort_values(key=abs, ascending=False)

print("=" * 70)
print("FEATURE CORRELATION WITH TARGET (CVD Mortality Rate)")
print("=" * 70)
print("\nRanked by absolute correlation:")
print("\n" + target_corr.to_string())

# Create bar plot
fig, ax = plt.subplots(figsize=(10, 12))

colors = ['green' if x > 0 else 'red' for x in target_corr.values]
target_corr.plot(kind='barh', color=colors, ax=ax)

plt.title('Weather Variables: Correlation with CVD Mortality Rate', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Pearson Correlation', fontsize=12, fontweight='bold')
plt.ylabel('Weather Variables', fontsize=12, fontweight='bold')
plt.axvline(x=0, color='black', linewidth=1)
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()

# Save high-resolution figure
plt.savefig(output_dir / 'weather_target_correlation_barplot.png', 
            dpi=300, bbox_inches='tight')
print("\n Saved: weather_target_correlation_barplot.png")
plt.show()

# Save to CSV
target_corr_df = pd.DataFrame({
    'Variable': target_corr.index,
    'Correlation with Target': target_corr.values
})
target_corr_df.to_csv(output_dir / 'weather_target_correlations.csv', index=False)
print(" Saved: weather_target_correlations.csv")
# Out:
# ======================================================================
# FEATURE CORRELATION WITH TARGET (CVD Mortality Rate)
# ======================================================================
#
# Ranked by absolute correlation:
#
# FoT Formaldehyde above75ᵗʰ percentile              0.586270
# FoT Isoprene above75ᵗʰ percentile                  0.527512
# FoT Peroxyacetyl Nitrate above75ᵗʰ percentile      0.526207
# Sulphate AOD at 550 nm                             0.513347
# Wet bulb temperature                               0.510466
# Isoprene                                           0.493279
# FoT Temperature below25ᵗʰ percentile              -0.478901
# Snow albedo                                        0.475728
# FoT Temperature above75ᵗʰ percentile               0.468300
# FoT Hydrogen peroxide above75ᵗʰ percentile         0.430864
# Sulphate aerosol mixing ratio                      0.402272
# Surface pressure                                   0.379511
# Dust AOD at 550 nm                                 0.378105
# Leaf area index, low vegetation                    0.350714
# Mean sea level pressure                            0.333193
# Hydroxyl radical                                  -0.332348
# Dust aerosol (0.55-0.9 µm) mixing ratio            0.302952
# FoT PM$_{2.5}$ above75ᵗʰ percentile                0.261083
# FoT Nitrogen monoxide above75ᵗʰ percentile        -0.260419
# Snow depth                                        -0.255734
# FoT Ozone above75ᵗʰ percentile                     0.251441
# Black carbon AOD at 550 nm                        -0.230920
# Hydrophilic black carbon aerosol mixing ratio     -0.222003
# Leaf area index, high vegetation                   0.213222
# FoT Hydroxyl radical above75ᵗʰ percentile         -0.199894
# 10m wind speed                                    -0.168241
# FoT Carbonmonoxide above75ᵗʰ percentile            0.150811
# Ethane                                            -0.138876
# FoT Sulphur dioxide above75ᵗʰ percentile           0.136411
# Land-sea mask                                      0.126702
# Relative humidity                                  0.121872
# Hydrophilic organic matter aerosol mixing ratio   -0.120973
# Sea salt aerosol (5-20 µm) mixing ratio           -0.108039
# Hydrophobic black carbon aerosol mixing ratio     -0.085147
# Hydrophobic organic matter aerosol mixing ratio   -0.084494
# FoT Nitric acid above75ᵗʰ percentile               0.084309
# Dust aerosol (0.9-20 µm) mixing ratio             -0.077412
# Sea salt AOD at 550 nm                             0.077231
# FoT Ethane above75ᵗʰ percentile                   -0.066828
# Fips                                              -0.060900
# Sea salt aerosol (0.5-5 µm) mixing ratio          -0.056774
# Sea salt aerosol (0.03-0.5 µm) mixing ratio       -0.046916
# Carbon monoxide                                    0.043683
# FoT Propane above75ᵗʰ percentile                  -0.040662
# FoT Nitrogen dioxide above75ᵗʰ percentile         -0.002694
# Organic matter AOD at 550 nm                      -0.002388
#
#  Saved: weather_target_correlation_barplot.png
#  Saved: weather_target_correlations.csv

# %% [markdown]
# ### 9.2 Bivariate Scatter Plots
#
# Visualize relationships between top correlated weather features and target variable.

# %%
# Select top 9 features by absolute correlation
top_features = target_corr.abs().nlargest(9).index.tolist()

# Create 3x3 subplot grid
fig, axes = plt.subplots(3, 3, figsize=(18, 14))
axes = axes.flatten()

for idx, feature in enumerate(top_features):
    ax = axes[idx]
    
    # Scatter plot with regression line
    ax.scatter(weather_df[feature], 
               weather_df['CVD Mortality Rate'],
               alpha=0.3, s=10, color='steelblue')
    
    # Add regression line
    z = np.polyfit(weather_df[feature].dropna(), 
                   weather_df.loc[weather_df[feature].notna(), 'CVD Mortality Rate'],
                   1)
    p = np.poly1d(z)
    ax.plot(weather_df[feature].sort_values(), 
            p(weather_df[feature].sort_values()),
            "r--", linewidth=2, alpha=0.8)
    
    # Labels and correlation
    corr_val = target_corr[feature]
    ax.set_xlabel(feature, fontsize=9, fontweight='bold')
    ax.set_ylabel('CVD Mortality Rate', fontsize=9, fontweight='bold')
    ax.set_title(f'r = {corr_val:.3f}', fontsize=10, fontweight='bold')
    ax.grid(alpha=0.3)

plt.suptitle('Top 9 Weather Features vs. CVD Mortality Rate', 
             fontsize=16, fontweight='bold', y=0.995)
plt.tight_layout()

# Save high-resolution figure
plt.savefig(output_dir / 'weather_top_features_scatter_plots.png', 
            dpi=300, bbox_inches='tight')
print(" Saved: weather_top_features_scatter_plots.png")
plt.show()
# Out:
#  Saved: weather_top_features_scatter_plots.png

# %% [markdown]
# ## 10. Multicollinearity Detection (VIF)
#
# Calculate Variance Inflation Factor (VIF) for each weather variable.
# - **VIF < 5**: Low multicollinearity
# - **VIF 5-10**: Moderate multicollinearity
# - **VIF > 10**: High multicollinearity (problematic)

# %%
# Prepare data for VIF calculation (remove any NaN values)
vif_data = weather_df[weather_cols].dropna()

print("=" * 70)
print("VARIANCE INFLATION FACTOR (VIF) ANALYSIS")
print("=" * 70)
print("\nCalculating VIF for each variable...")
print("(This may take several minutes for 35+ variables)\n")

# Calculate VIF for each feature
vif_results = []
for i, col in enumerate(weather_cols):
    try:
        vif_value = variance_inflation_factor(vif_data.values, i)
        vif_results.append({
            'Variable': col,
            'VIF': vif_value
        })
        print(f"  ✓ [{i+1}/{len(weather_cols)}] {col}: VIF = {vif_value:.2f}")
    except Exception as e:
        print(f"  ✗ [{i+1}/{len(weather_cols)}] {col}: Error calculating VIF ({str(e)})")
        vif_results.append({
            'Variable': col,
            'VIF': np.nan
        })

# Create VIF dataframe
vif_df = pd.DataFrame(vif_results)
vif_df = vif_df.sort_values('VIF', ascending=False)

print("\n" + "=" * 70)
print("VIF RESULTS (sorted by VIF value):")
print("=" * 70)
print("\n" + vif_df.to_string(index=False))

# Interpretation
high_vif = vif_df[vif_df['VIF'] > 10]
if len(high_vif) > 0:
    print(f"\n⚠ {len(high_vif)} variables with VIF > 10 (high multicollinearity):")
    for _, row in high_vif.iterrows():
        print(f"  - {row['Variable']}: VIF = {row['VIF']:.2f}")
else:
    print("\n No variables with VIF > 10")

# Save to CSV
vif_df.to_csv(output_dir / 'weather_vif_analysis.csv', index=False)
print("\n Saved: weather_vif_analysis.csv")
# Out:
# ======================================================================
# VARIANCE INFLATION FACTOR (VIF) ANALYSIS
# ======================================================================
#
# Calculating VIF for each variable...
# (This may take several minutes for 35+ variables)
#
#   ✓ [1/46] Fips: VIF = 7.13
#   ✓ [2/46] Black carbon AOD at 550 nm: VIF = 267.70
#   ✓ [3/46] Dust AOD at 550 nm: VIF = 54.47
#   ✓ [4/46] Land-sea mask: VIF = 294.68
#   ✓ [5/46] Mean sea level pressure: VIF = 22029.07
#   ✓ [6/46] Organic matter AOD at 550 nm: VIF = 1375.29
#   ✓ [7/46] Sea salt AOD at 550 nm: VIF = 67.10
#   ✓ [8/46] Sulphate AOD at 550 nm: VIF = 332.71
#   ✓ [9/46] Surface pressure: VIF = 8825.23
#   ✓ [10/46] Carbon monoxide: VIF = 1201.94
#   ✓ [11/46] Dust aerosol (0.55-0.9 µm) mixing ratio: VIF = 106.60
#   ✓ [12/46] Dust aerosol (0.9-20 µm) mixing ratio: VIF = 7.87
#   ✓ [13/46] Ethane: VIF = 1147.93
#   ✓ [14/46] Hydrophilic black carbon aerosol mixing ratio: VIF = 173.73
#   ✓ [15/46] Hydrophilic organic matter aerosol mixing ratio: VIF = 1048.95
#   ✓ [16/46] Hydrophobic black carbon aerosol mixing ratio: VIF = 35.42
#   ✓ [17/46] Hydrophobic organic matter aerosol mixing ratio: VIF = 438.29
#   ✓ [18/46] Hydroxyl radical: VIF = 268.69
#   ✓ [19/46] Isoprene: VIF = 41.06
#   ✓ [20/46] Sea salt aerosol (0.03-0.5 µm) mixing ratio: VIF = 1161.34
#   ✓ [21/46] Sea salt aerosol (0.5-5 µm) mixing ratio: VIF = 149.68
#   ✓ [22/46] Sea salt aerosol (5-20 µm) mixing ratio: VIF = 44.32
#   ✓ [23/46] Sulphate aerosol mixing ratio: VIF = 271.07
#   ✓ [24/46] Leaf area index, high vegetation: VIF = 18.32
#   ✓ [25/46] Leaf area index, low vegetation: VIF = 16.84
#   ✓ [26/46] Snow albedo: VIF = 8663.62
#   ✓ [27/46] Snow depth: VIF = 3.60
#   ✓ [28/46] Relative humidity: VIF = 432.55
#   ✓ [29/46] 10m wind speed: VIF = 15.12
#   ✓ [30/46] Wet bulb temperature: VIF = 262.15
#   ✓ [31/46] FoT Carbonmonoxide above75ᵗʰ percentile: VIF = 208.93
#   ✓ [32/46] FoT Ethane above75ᵗʰ percentile: VIF = 133.56
#   ✓ [33/46] FoT Formaldehyde above75ᵗʰ percentile: VIF = 168.08
#   ✓ [34/46] FoT Hydroxyl radical above75ᵗʰ percentile: VIF = 328.36
#   ✓ [35/46] FoT Isoprene above75ᵗʰ percentile: VIF = 63.84
#   ✓ [36/46] FoT Peroxyacetyl Nitrate above75ᵗʰ percentile: VIF = 173.93
#   ✓ [37/46] FoT Nitric acid above75ᵗʰ percentile: VIF = 78.37
#   ✓ [38/46] FoT Nitrogen dioxide above75ᵗʰ percentile: VIF = 123.87
#   ✓ [39/46] FoT Nitrogen monoxide above75ᵗʰ percentile: VIF = 46.57
#   ✓ [40/46] FoT Ozone above75ᵗʰ percentile: VIF = 234.90
#   ✓ [41/46] FoT Hydrogen peroxide above75ᵗʰ percentile: VIF = 197.87
#   ✓ [42/46] FoT PM$_{2.5}$ above75ᵗʰ percentile: VIF = 201.77
#   ✓ [43/46] FoT Propane above75ᵗʰ percentile: VIF = 36.23
#   ✓ [44/46] FoT Sulphur dioxide above75ᵗʰ percentile: VIF = 15.77
#   ✓ [45/46] FoT Temperature above75ᵗʰ percentile: VIF = 393.65
#   ✓ [46/46] FoT Temperature below25ᵗʰ percentile: VIF = 328.23
#
# ======================================================================
# VIF RESULTS (sorted by VIF value):
# ======================================================================
#
#                                        Variable          VIF
#                         Mean sea level pressure 22029.070679
#                                Surface pressure  8825.226869
#                                     Snow albedo  8663.622685
#                    Organic matter AOD at 550 nm  1375.290870
#                                 Carbon monoxide  1201.942617
#     Sea salt aerosol (0.03-0.5 µm) mixing ratio  1161.343885
#                                          Ethane  1147.931782
# Hydrophilic organic matter aerosol mixing ratio  1048.954878
# Hydrophobic organic matter aerosol mixing ratio   438.286586
#                               Relative humidity   432.553132
#            FoT Temperature above75ᵗʰ percentile   393.652610
#                          Sulphate AOD at 550 nm   332.709913
#       FoT Hydroxyl radical above75ᵗʰ percentile   328.360871
#            FoT Temperature below25ᵗʰ percentile   328.227681
#                                   Land-sea mask   294.678471
#                   Sulphate aerosol mixing ratio   271.071893
#                                Hydroxyl radical   268.693702
#                      Black carbon AOD at 550 nm   267.703866
#                            Wet bulb temperature   262.150622
#                  FoT Ozone above75ᵗʰ percentile   234.898364
#         FoT Carbonmonoxide above75ᵗʰ percentile   208.934552
#             FoT PM$_{2.5}$ above75ᵗʰ percentile   201.771677
#      FoT Hydrogen peroxide above75ᵗʰ percentile   197.866218
#   FoT Peroxyacetyl Nitrate above75ᵗʰ percentile   173.934684
#   Hydrophilic black carbon aerosol mixing ratio   173.730746
#           FoT Formaldehyde above75ᵗʰ percentile   168.080223
#        Sea salt aerosol (0.5-5 µm) mixing ratio   149.678007
#                 FoT Ethane above75ᵗʰ percentile   133.560429
#       FoT Nitrogen dioxide above75ᵗʰ percentile   123.869414
#         Dust aerosol (0.55-0.9 µm) mixing ratio   106.604477
#            FoT Nitric acid above75ᵗʰ percentile    78.373921
#                          Sea salt AOD at 550 nm    67.098923
#               FoT Isoprene above75ᵗʰ percentile    63.836262
#                              Dust AOD at 550 nm    54.473912
#      FoT Nitrogen monoxide above75ᵗʰ percentile    46.572981
#         Sea salt aerosol (5-20 µm) mixing ratio    44.317470
#                                        Isoprene    41.059851
#                FoT Propane above75ᵗʰ percentile    36.228503
#   Hydrophobic black carbon aerosol mixing ratio    35.419174
#                Leaf area index, high vegetation    18.317669
#                 Leaf area index, low vegetation    16.835269
#        FoT Sulphur dioxide above75ᵗʰ percentile    15.767383
#                                  10m wind speed    15.124393
#           Dust aerosol (0.9-20 µm) mixing ratio     7.868591
#                                            Fips     7.126878
#                                      Snow depth     3.599773
#
# ⚠ 43 variables with VIF > 10 (high multicollinearity):
#   - Mean sea level pressure: VIF = 22029.07
#   - Surface pressure: VIF = 8825.23
#   - Snow albedo: VIF = 8663.62
#   - Organic matter AOD at 550 nm: VIF = 1375.29
#   - Carbon monoxide: VIF = 1201.94
#   - Sea salt aerosol (0.03-0.5 µm) mixing ratio: VIF = 1161.34
#   - Ethane: VIF = 1147.93
#   - Hydrophilic organic matter aerosol mixing ratio: VIF = 1048.95
#   - Hydrophobic organic matter aerosol mixing ratio: VIF = 438.29
#   - Relative humidity: VIF = 432.55
#   - FoT Temperature above75ᵗʰ percentile: VIF = 393.65
#   - Sulphate AOD at 550 nm: VIF = 332.71
#   - FoT Hydroxyl radical above75ᵗʰ percentile: VIF = 328.36
#   - FoT Temperature below25ᵗʰ percentile: VIF = 328.23
#   - Land-sea mask: VIF = 294.68
#   - Sulphate aerosol mixing ratio: VIF = 271.07
#   - Hydroxyl radical: VIF = 268.69
#   - Black carbon AOD at 550 nm: VIF = 267.70
#   - Wet bulb temperature: VIF = 262.15
#   - FoT Ozone above75ᵗʰ percentile: VIF = 234.90
#   - FoT Carbonmonoxide above75ᵗʰ percentile: VIF = 208.93
#   - FoT PM$_{2.5}$ above75ᵗʰ percentile: VIF = 201.77
#   - FoT Hydrogen peroxide above75ᵗʰ percentile: VIF = 197.87
#   - FoT Peroxyacetyl Nitrate above75ᵗʰ percentile: VIF = 173.93
#   - Hydrophilic black carbon aerosol mixing ratio: VIF = 173.73
#   - FoT Formaldehyde above75ᵗʰ percentile: VIF = 168.08
#   - Sea salt aerosol (0.5-5 µm) mixing ratio: VIF = 149.68
#   - FoT Ethane above75ᵗʰ percentile: VIF = 133.56
#   - FoT Nitrogen dioxide above75ᵗʰ percentile: VIF = 123.87
#   - Dust aerosol (0.55-0.9 µm) mixing ratio: VIF = 106.60
#   - FoT Nitric acid above75ᵗʰ percentile: VIF = 78.37
#   - Sea salt AOD at 550 nm: VIF = 67.10
#   - FoT Isoprene above75ᵗʰ percentile: VIF = 63.84
#   - Dust AOD at 550 nm: VIF = 54.47
#   - FoT Nitrogen monoxide above75ᵗʰ percentile: VIF = 46.57
#   - Sea salt aerosol (5-20 µm) mixing ratio: VIF = 44.32
#   - Isoprene: VIF = 41.06
#   - FoT Propane above75ᵗʰ percentile: VIF = 36.23
#   - Hydrophobic black carbon aerosol mixing ratio: VIF = 35.42
#   - Leaf area index, high vegetation: VIF = 18.32
#   - Leaf area index, low vegetation: VIF = 16.84
#   - FoT Sulphur dioxide above75ᵗʰ percentile: VIF = 15.77
#   - 10m wind speed: VIF = 15.12
#
#  Saved: weather_vif_analysis.csv

# %%
# Visualize VIF values
fig, ax = plt.subplots(figsize=(10, 12))

# Color code by severity
colors = ['green' if x < 5 else 'orange' if x < 10 else 'red' 
          for x in vif_df['VIF'].values]

vif_df.set_index('Variable')['VIF'].plot(kind='barh', color=colors, ax=ax)

plt.title('Weather Variables: Variance Inflation Factor (VIF)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('VIF Value', fontsize=12, fontweight='bold')
plt.ylabel('Weather Variables', fontsize=12, fontweight='bold')

# Add reference lines
plt.axvline(x=5, color='orange', linestyle='--', linewidth=1.5, 
            alpha=0.7, label='VIF = 5 (Moderate threshold)')
plt.axvline(x=10, color='red', linestyle='--', linewidth=1.5, 
            alpha=0.7, label='VIF = 10 (High threshold)')

plt.legend(loc='lower right', fontsize=10)
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()

# Save high-resolution figure
plt.savefig(output_dir / 'weather_vif_barplot.png', 
            dpi=300, bbox_inches='tight')
print(" Saved: weather_vif_barplot.png")
plt.show()
# Out:
#  Saved: weather_vif_barplot.png

# %% [markdown]
# ## 11. Decision Framework
#
# ### 11.1 Combine All Metrics
#
# Create comprehensive table with all relevant metrics for decision-making.

# %%
# Combine all metrics into one dataframe
decision_df = pd.DataFrame({
    'Variable': weather_cols,
    'Target_Correlation': [target_corr[col] for col in weather_cols],
    'Abs_Target_Correlation': [abs(target_corr[col]) for col in weather_cols],
    'VIF': [vif_df[vif_df['Variable'] == col]['VIF'].values[0] if col in vif_df['Variable'].values else np.nan 
            for col in weather_cols]
})

# Sort by absolute target correlation (descending)
decision_df = decision_df.sort_values('Abs_Target_Correlation', ascending=False)

print("=" * 70)
print("COMPREHENSIVE DECISION METRICS")
print("=" * 70)
print("\n" + decision_df.to_string(index=False))

# Save to CSV
decision_df.to_csv(output_dir / 'weather_feature_decision_metrics.csv', index=False)
print("\n Saved: weather_feature_decision_metrics.csv")
# Out:
# ======================================================================
# COMPREHENSIVE DECISION METRICS
# ======================================================================
#
#                                        Variable  Target_Correlation  Abs_Target_Correlation          VIF
#           FoT Formaldehyde above75ᵗʰ percentile            0.586270                0.586270   168.080223
#               FoT Isoprene above75ᵗʰ percentile            0.527512                0.527512    63.836262
#   FoT Peroxyacetyl Nitrate above75ᵗʰ percentile            0.526207                0.526207   173.934684
#                          Sulphate AOD at 550 nm            0.513347                0.513347   332.709913
#                            Wet bulb temperature            0.510466                0.510466   262.150622
#                                        Isoprene            0.493279                0.493279    41.059851
#            FoT Temperature below25ᵗʰ percentile           -0.478901                0.478901   328.227681
#                                     Snow albedo            0.475728                0.475728  8663.622685
#            FoT Temperature above75ᵗʰ percentile            0.468300                0.468300   393.652610
#      FoT Hydrogen peroxide above75ᵗʰ percentile            0.430864                0.430864   197.866218
#                   Sulphate aerosol mixing ratio            0.402272                0.402272   271.071893
#                                Surface pressure            0.379511                0.379511  8825.226869
#                              Dust AOD at 550 nm            0.378105                0.378105    54.473912
#                 Leaf area index, low vegetation            0.350714                0.350714    16.835269
#                         Mean sea level pressure            0.333193                0.333193 22029.070679
#                                Hydroxyl radical           -0.332348                0.332348   268.693702
#         Dust aerosol (0.55-0.9 µm) mixing ratio            0.302952                0.302952   106.604477
#             FoT PM$_{2.5}$ above75ᵗʰ percentile            0.261083                0.261083   201.771677
#      FoT Nitrogen monoxide above75ᵗʰ percentile           -0.260419                0.260419    46.572981
#                                      Snow depth           -0.255734                0.255734     3.599773
#                  FoT Ozone above75ᵗʰ percentile            0.251441                0.251441   234.898364
#                      Black carbon AOD at 550 nm           -0.230920                0.230920   267.703866
#   Hydrophilic black carbon aerosol mixing ratio           -0.222003                0.222003   173.730746
#                Leaf area index, high vegetation            0.213222                0.213222    18.317669
#       FoT Hydroxyl radical above75ᵗʰ percentile           -0.199894                0.199894   328.360871
#                                  10m wind speed           -0.168241                0.168241    15.124393
#         FoT Carbonmonoxide above75ᵗʰ percentile            0.150811                0.150811   208.934552
#                                          Ethane           -0.138876                0.138876  1147.931782
#        FoT Sulphur dioxide above75ᵗʰ percentile            0.136411                0.136411    15.767383
#                                   Land-sea mask            0.126702                0.126702   294.678471
#                               Relative humidity            0.121872                0.121872   432.553132
# Hydrophilic organic matter aerosol mixing ratio           -0.120973                0.120973  1048.954878
#         Sea salt aerosol (5-20 µm) mixing ratio           -0.108039                0.108039    44.317470
#   Hydrophobic black carbon aerosol mixing ratio           -0.085147                0.085147    35.419174
# Hydrophobic organic matter aerosol mixing ratio           -0.084494                0.084494   438.286586
#            FoT Nitric acid above75ᵗʰ percentile            0.084309                0.084309    78.373921
#           Dust aerosol (0.9-20 µm) mixing ratio           -0.077412                0.077412     7.868591
#                          Sea salt AOD at 550 nm            0.077231                0.077231    67.098923
#                 FoT Ethane above75ᵗʰ percentile           -0.066828                0.066828   133.560429
#                                            Fips           -0.060900                0.060900     7.126878
#        Sea salt aerosol (0.5-5 µm) mixing ratio           -0.056774                0.056774   149.678007
#     Sea salt aerosol (0.03-0.5 µm) mixing ratio           -0.046916                0.046916  1161.343885
#                                 Carbon monoxide            0.043683                0.043683  1201.942617
#                FoT Propane above75ᵗʰ percentile           -0.040662                0.040662    36.228503
#       FoT Nitrogen dioxide above75ᵗʰ percentile           -0.002694                0.002694   123.869414
#                    Organic matter AOD at 550 nm           -0.002388                0.002388  1375.290870
#
#  Saved: weather_feature_decision_metrics.csv

# %% [markdown]
# ### 11.2 Decision Guidelines
#
# For each highly correlated pair (|r| > 0.85), apply the following decision rules:
#
# **Decision Criteria:**
# 1. **Target Correlation**: Keep variable with higher |correlation| with CVD Mortality Rate
# 2. **VIF**: Prefer variable with lower VIF (less multicollinearity)
# 3. **Interpretability**: If metrics are similar, keep more interpretable variable
#
# **Actions:**
# - Document which variable to **KEEP** and which to **DROP**
# - Provide clear reasoning for each decision

# %%
print("=" * 70)
print("FEATURE SELECTION RECOMMENDATIONS")
print("=" * 70)

if 'high_corr_df' in locals() and len(high_corr_df) > 0:
    print(f"\nAnalyzing {len(high_corr_df)} highly correlated pairs...\n")
    
    recommendations = []
    
    for idx, row in high_corr_df.iterrows():
        var1 = row['Variable 1']
        var2 = row['Variable 2']
        corr = row['Correlation']
        
        # Get metrics for both variables
        var1_metrics = decision_df[decision_df['Variable'] == var1].iloc[0]
        var2_metrics = decision_df[decision_df['Variable'] == var2].iloc[0]
        
        print(f"Pair {idx+1}: {var1} vs {var2}")
        print(f"  Inter-correlation: {corr:.3f}")
        print(f"\n  {var1}:")
        print(f"    - Target correlation: {var1_metrics['Target_Correlation']:.3f}")
        print(f"    - VIF: {var1_metrics['VIF']:.2f}")
        print(f"\n  {var2}:")
        print(f"    - Target correlation: {var2_metrics['Target_Correlation']:.3f}")
        print(f"    - VIF: {var2_metrics['VIF']:.2f}")
        
        # Decision logic
        var1_score = var1_metrics['Abs_Target_Correlation'] - (var1_metrics['VIF'] / 100)
        var2_score = var2_metrics['Abs_Target_Correlation'] - (var2_metrics['VIF'] / 100)
        
        if var1_score > var2_score:
            keep, drop = var1, var2
            reason = f"Higher target correlation ({var1_metrics['Abs_Target_Correlation']:.3f} vs {var2_metrics['Abs_Target_Correlation']:.3f})"
        else:
            keep, drop = var2, var1
            reason = f"Higher target correlation ({var2_metrics['Abs_Target_Correlation']:.3f} vs {var1_metrics['Abs_Target_Correlation']:.3f})"
        
        print(f"\n  → RECOMMENDATION: KEEP '{keep}', DROP '{drop}'")
        print(f"    Reason: {reason}")
        print("\n" + "-" * 70 + "\n")
        
        recommendations.append({
            'Correlated Pair': f"{var1} <-> {var2}",
            'Correlation': corr,
            'Keep': keep,
            'Drop': drop,
            'Reason': reason
        })
    
    # Save recommendations
    recommendations_df = pd.DataFrame(recommendations)
    recommendations_df.to_csv(output_dir / 'weather_feature_selection_recommendations.csv', index=False)
    print(" Saved: weather_feature_selection_recommendations.csv")
    
else:
    print("\n No highly correlated pairs detected.")
    print("  All weather features can be retained.")
# Out:
# ======================================================================
# FEATURE SELECTION RECOMMENDATIONS
# ======================================================================
#
# Analyzing 26 highly correlated pairs...
#
# Pair 15: Sea salt aerosol (0.03-0.5 µm) mixing ratio vs Sea salt aerosol (0.5-5 µm) mixing ratio
#   Inter-correlation: 1.000
#
#   Sea salt aerosol (0.03-0.5 µm) mixing ratio:
#     - Target correlation: -0.047
#     - VIF: 1161.34
#
#   Sea salt aerosol (0.5-5 µm) mixing ratio:
#     - Target correlation: -0.057
#     - VIF: 149.68
#
#   → RECOMMENDATION: KEEP 'Sea salt aerosol (0.5-5 µm) mixing ratio', DROP 'Sea salt aerosol (0.03-0.5 µm) mixing ratio'
#     Reason: Higher target correlation (0.057 vs 0.047)
#
# ----------------------------------------------------------------------
#
# Pair 20: Wet bulb temperature vs FoT Temperature below25ᵗʰ percentile
#   Inter-correlation: -0.967
#
#   Wet bulb temperature:
#     - Target correlation: 0.510
#     - VIF: 262.15
#
#   FoT Temperature below25ᵗʰ percentile:
#     - Target correlation: -0.479
#     - VIF: 328.23
#
#   → RECOMMENDATION: KEEP 'Wet bulb temperature', DROP 'FoT Temperature below25ᵗʰ percentile'
#     Reason: Higher target correlation (0.510 vs 0.479)
#
# ----------------------------------------------------------------------
#
# Pair 26: FoT Temperature above75ᵗʰ percentile vs FoT Temperature below25ᵗʰ percentile
#   Inter-correlation: -0.954
#
#   FoT Temperature above75ᵗʰ percentile:
#     - Target correlation: 0.468
#     - VIF: 393.65
#
#   FoT Temperature below25ᵗʰ percentile:
#     - Target correlation: -0.479
#     - VIF: 328.23
#
#   → RECOMMENDATION: KEEP 'FoT Temperature below25ᵗʰ percentile', DROP 'FoT Temperature above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.479 vs 0.468)
#
# ----------------------------------------------------------------------
#
# Pair 14: Isoprene vs FoT Isoprene above75ᵗʰ percentile
#   Inter-correlation: 0.943
#
#   Isoprene:
#     - Target correlation: 0.493
#     - VIF: 41.06
#
#   FoT Isoprene above75ᵗʰ percentile:
#     - Target correlation: 0.528
#     - VIF: 63.84
#
#   → RECOMMENDATION: KEEP 'Isoprene', DROP 'FoT Isoprene above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.493 vs 0.528)
#
# ----------------------------------------------------------------------
#
# Pair 17: Sea salt aerosol (0.5-5 µm) mixing ratio vs Sea salt aerosol (5-20 µm) mixing ratio
#   Inter-correlation: 0.937
#
#   Sea salt aerosol (0.5-5 µm) mixing ratio:
#     - Target correlation: -0.057
#     - VIF: 149.68
#
#   Sea salt aerosol (5-20 µm) mixing ratio:
#     - Target correlation: -0.108
#     - VIF: 44.32
#
#   → RECOMMENDATION: KEEP 'Sea salt aerosol (5-20 µm) mixing ratio', DROP 'Sea salt aerosol (0.5-5 µm) mixing ratio'
#     Reason: Higher target correlation (0.108 vs 0.057)
#
# ----------------------------------------------------------------------
#
# Pair 22: FoT Formaldehyde above75ᵗʰ percentile vs FoT Isoprene above75ᵗʰ percentile
#   Inter-correlation: 0.935
#
#   FoT Formaldehyde above75ᵗʰ percentile:
#     - Target correlation: 0.586
#     - VIF: 168.08
#
#   FoT Isoprene above75ᵗʰ percentile:
#     - Target correlation: 0.528
#     - VIF: 63.84
#
#   → RECOMMENDATION: KEEP 'FoT Isoprene above75ᵗʰ percentile', DROP 'FoT Formaldehyde above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.528 vs 0.586)
#
# ----------------------------------------------------------------------
#
# Pair 19: Wet bulb temperature vs FoT Temperature above75ᵗʰ percentile
#   Inter-correlation: 0.933
#
#   Wet bulb temperature:
#     - Target correlation: 0.510
#     - VIF: 262.15
#
#   FoT Temperature above75ᵗʰ percentile:
#     - Target correlation: 0.468
#     - VIF: 393.65
#
#   → RECOMMENDATION: KEEP 'Wet bulb temperature', DROP 'FoT Temperature above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.510 vs 0.468)
#
# ----------------------------------------------------------------------
#
# Pair 16: Sea salt aerosol (0.03-0.5 µm) mixing ratio vs Sea salt aerosol (5-20 µm) mixing ratio
#   Inter-correlation: 0.931
#
#   Sea salt aerosol (0.03-0.5 µm) mixing ratio:
#     - Target correlation: -0.047
#     - VIF: 1161.34
#
#   Sea salt aerosol (5-20 µm) mixing ratio:
#     - Target correlation: -0.108
#     - VIF: 44.32
#
#   → RECOMMENDATION: KEEP 'Sea salt aerosol (5-20 µm) mixing ratio', DROP 'Sea salt aerosol (0.03-0.5 µm) mixing ratio'
#     Reason: Higher target correlation (0.108 vs 0.047)
#
# ----------------------------------------------------------------------
#
# Pair 24: FoT Hydrogen peroxide above75ᵗʰ percentile vs FoT Temperature above75ᵗʰ percentile
#   Inter-correlation: 0.931
#
#   FoT Hydrogen peroxide above75ᵗʰ percentile:
#     - Target correlation: 0.431
#     - VIF: 197.87
#
#   FoT Temperature above75ᵗʰ percentile:
#     - Target correlation: 0.468
#     - VIF: 393.65
#
#   → RECOMMENDATION: KEEP 'FoT Hydrogen peroxide above75ᵗʰ percentile', DROP 'FoT Temperature above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.431 vs 0.468)
#
# ----------------------------------------------------------------------
#
# Pair 10: Hydrophilic organic matter aerosol mixing ratio vs Hydrophobic organic matter aerosol mixing ratio
#   Inter-correlation: 0.930
#
#   Hydrophilic organic matter aerosol mixing ratio:
#     - Target correlation: -0.121
#     - VIF: 1048.95
#
#   Hydrophobic organic matter aerosol mixing ratio:
#     - Target correlation: -0.084
#     - VIF: 438.29
#
#   → RECOMMENDATION: KEEP 'Hydrophobic organic matter aerosol mixing ratio', DROP 'Hydrophilic organic matter aerosol mixing ratio'
#     Reason: Higher target correlation (0.084 vs 0.121)
#
# ----------------------------------------------------------------------
#
# Pair 23: FoT Formaldehyde above75ᵗʰ percentile vs FoT Peroxyacetyl Nitrate above75ᵗʰ percentile
#   Inter-correlation: 0.919
#
#   FoT Formaldehyde above75ᵗʰ percentile:
#     - Target correlation: 0.586
#     - VIF: 168.08
#
#   FoT Peroxyacetyl Nitrate above75ᵗʰ percentile:
#     - Target correlation: 0.526
#     - VIF: 173.93
#
#   → RECOMMENDATION: KEEP 'FoT Formaldehyde above75ᵗʰ percentile', DROP 'FoT Peroxyacetyl Nitrate above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.586 vs 0.526)
#
# ----------------------------------------------------------------------
#
# Pair 1: Dust AOD at 550 nm vs Dust aerosol (0.55-0.9 µm) mixing ratio
#   Inter-correlation: 0.915
#
#   Dust AOD at 550 nm:
#     - Target correlation: 0.378
#     - VIF: 54.47
#
#   Dust aerosol (0.55-0.9 µm) mixing ratio:
#     - Target correlation: 0.303
#     - VIF: 106.60
#
#   → RECOMMENDATION: KEEP 'Dust AOD at 550 nm', DROP 'Dust aerosol (0.55-0.9 µm) mixing ratio'
#     Reason: Higher target correlation (0.378 vs 0.303)
#
# ----------------------------------------------------------------------
#
# Pair 12: Hydroxyl radical vs FoT Hydroxyl radical above75ᵗʰ percentile
#   Inter-correlation: 0.893
#
#   Hydroxyl radical:
#     - Target correlation: -0.332
#     - VIF: 268.69
#
#   FoT Hydroxyl radical above75ᵗʰ percentile:
#     - Target correlation: -0.200
#     - VIF: 328.36
#
#   → RECOMMENDATION: KEEP 'Hydroxyl radical', DROP 'FoT Hydroxyl radical above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.332 vs 0.200)
#
# ----------------------------------------------------------------------
#
# Pair 3: Sea salt AOD at 550 nm vs Sea salt aerosol (0.03-0.5 µm) mixing ratio
#   Inter-correlation: 0.886
#
#   Sea salt AOD at 550 nm:
#     - Target correlation: 0.077
#     - VIF: 67.10
#
#   Sea salt aerosol (0.03-0.5 µm) mixing ratio:
#     - Target correlation: -0.047
#     - VIF: 1161.34
#
#   → RECOMMENDATION: KEEP 'Sea salt AOD at 550 nm', DROP 'Sea salt aerosol (0.03-0.5 µm) mixing ratio'
#     Reason: Higher target correlation (0.077 vs 0.047)
#
# ----------------------------------------------------------------------
#
# Pair 9: Ethane vs Hydrophobic organic matter aerosol mixing ratio
#   Inter-correlation: 0.886
#
#   Ethane:
#     - Target correlation: -0.139
#     - VIF: 1147.93
#
#   Hydrophobic organic matter aerosol mixing ratio:
#     - Target correlation: -0.084
#     - VIF: 438.29
#
#   → RECOMMENDATION: KEEP 'Hydrophobic organic matter aerosol mixing ratio', DROP 'Ethane'
#     Reason: Higher target correlation (0.084 vs 0.139)
#
# ----------------------------------------------------------------------
#
# Pair 4: Sea salt AOD at 550 nm vs Sea salt aerosol (0.5-5 µm) mixing ratio
#   Inter-correlation: 0.881
#
#   Sea salt AOD at 550 nm:
#     - Target correlation: 0.077
#     - VIF: 67.10
#
#   Sea salt aerosol (0.5-5 µm) mixing ratio:
#     - Target correlation: -0.057
#     - VIF: 149.68
#
#   → RECOMMENDATION: KEEP 'Sea salt AOD at 550 nm', DROP 'Sea salt aerosol (0.5-5 µm) mixing ratio'
#     Reason: Higher target correlation (0.077 vs 0.057)
#
# ----------------------------------------------------------------------
#
# Pair 8: Ethane vs Hydrophobic black carbon aerosol mixing ratio
#   Inter-correlation: 0.881
#
#   Ethane:
#     - Target correlation: -0.139
#     - VIF: 1147.93
#
#   Hydrophobic black carbon aerosol mixing ratio:
#     - Target correlation: -0.085
#     - VIF: 35.42
#
#   → RECOMMENDATION: KEEP 'Hydrophobic black carbon aerosol mixing ratio', DROP 'Ethane'
#     Reason: Higher target correlation (0.085 vs 0.139)
#
# ----------------------------------------------------------------------
#
# Pair 21: FoT Ethane above75ᵗʰ percentile vs FoT Propane above75ᵗʰ percentile
#   Inter-correlation: 0.877
#
#   FoT Ethane above75ᵗʰ percentile:
#     - Target correlation: -0.067
#     - VIF: 133.56
#
#   FoT Propane above75ᵗʰ percentile:
#     - Target correlation: -0.041
#     - VIF: 36.23
#
#   → RECOMMENDATION: KEEP 'FoT Propane above75ᵗʰ percentile', DROP 'FoT Ethane above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.041 vs 0.067)
#
# ----------------------------------------------------------------------
#
# Pair 25: FoT Hydrogen peroxide above75ᵗʰ percentile vs FoT Temperature below25ᵗʰ percentile
#   Inter-correlation: -0.873
#
#   FoT Hydrogen peroxide above75ᵗʰ percentile:
#     - Target correlation: 0.431
#     - VIF: 197.87
#
#   FoT Temperature below25ᵗʰ percentile:
#     - Target correlation: -0.479
#     - VIF: 328.23
#
#   → RECOMMENDATION: KEEP 'FoT Hydrogen peroxide above75ᵗʰ percentile', DROP 'FoT Temperature below25ᵗʰ percentile'
#     Reason: Higher target correlation (0.431 vs 0.479)
#
# ----------------------------------------------------------------------
#
# Pair 2: Dust AOD at 550 nm vs FoT Hydrogen peroxide above75ᵗʰ percentile
#   Inter-correlation: 0.870
#
#   Dust AOD at 550 nm:
#     - Target correlation: 0.378
#     - VIF: 54.47
#
#   FoT Hydrogen peroxide above75ᵗʰ percentile:
#     - Target correlation: 0.431
#     - VIF: 197.87
#
#   → RECOMMENDATION: KEEP 'Dust AOD at 550 nm', DROP 'FoT Hydrogen peroxide above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.378 vs 0.431)
#
# ----------------------------------------------------------------------
#
# Pair 13: Isoprene vs FoT Formaldehyde above75ᵗʰ percentile
#   Inter-correlation: 0.868
#
#   Isoprene:
#     - Target correlation: 0.493
#     - VIF: 41.06
#
#   FoT Formaldehyde above75ᵗʰ percentile:
#     - Target correlation: 0.586
#     - VIF: 168.08
#
#   → RECOMMENDATION: KEEP 'Isoprene', DROP 'FoT Formaldehyde above75ᵗʰ percentile'
#     Reason: Higher target correlation (0.493 vs 0.586)
#
# ----------------------------------------------------------------------
#
# Pair 5: Sulphate AOD at 550 nm vs Sulphate aerosol mixing ratio
#   Inter-correlation: 0.866
#
#   Sulphate AOD at 550 nm:
#     - Target correlation: 0.513
#     - VIF: 332.71
#
#   Sulphate aerosol mixing ratio:
#     - Target correlation: 0.402
#     - VIF: 271.07
#
#   → RECOMMENDATION: KEEP 'Sulphate aerosol mixing ratio', DROP 'Sulphate AOD at 550 nm'
#     Reason: Higher target correlation (0.402 vs 0.513)
#
# ----------------------------------------------------------------------
#
# Pair 6: Carbon monoxide vs Ethane
#   Inter-correlation: 0.863
#
#   Carbon monoxide:
#     - Target correlation: 0.044
#     - VIF: 1201.94
#
#   Ethane:
#     - Target correlation: -0.139
#     - VIF: 1147.93
#
#   → RECOMMENDATION: KEEP 'Ethane', DROP 'Carbon monoxide'
#     Reason: Higher target correlation (0.139 vs 0.044)
#
# ----------------------------------------------------------------------
#
# Pair 7: Carbon monoxide vs Hydrophobic organic matter aerosol mixing ratio
#   Inter-correlation: 0.857
#
#   Carbon monoxide:
#     - Target correlation: 0.044
#     - VIF: 1201.94
#
#   Hydrophobic organic matter aerosol mixing ratio:
#     - Target correlation: -0.084
#     - VIF: 438.29
#
#   → RECOMMENDATION: KEEP 'Hydrophobic organic matter aerosol mixing ratio', DROP 'Carbon monoxide'
#     Reason: Higher target correlation (0.084 vs 0.044)
#
# ----------------------------------------------------------------------
#
# Pair 11: Hydrophobic black carbon aerosol mixing ratio vs Hydrophobic organic matter aerosol mixing ratio
#   Inter-correlation: 0.856
#
#   Hydrophobic black carbon aerosol mixing ratio:
#     - Target correlation: -0.085
#     - VIF: 35.42
#
#   Hydrophobic organic matter aerosol mixing ratio:
#     - Target correlation: -0.084
#     - VIF: 438.29
#
#   → RECOMMENDATION: KEEP 'Hydrophobic black carbon aerosol mixing ratio', DROP 'Hydrophobic organic matter aerosol mixing ratio'
#     Reason: Higher target correlation (0.085 vs 0.084)
#
# ----------------------------------------------------------------------
#
# Pair 18: Wet bulb temperature vs FoT Hydrogen peroxide above75ᵗʰ percentile
#   Inter-correlation: 0.853
#
#   Wet bulb temperature:
#     - Target correlation: 0.510
#     - VIF: 262.15
#
#   FoT Hydrogen peroxide above75ᵗʰ percentile:
#     - Target correlation: 0.431
#     - VIF: 197.87
#
#   → RECOMMENDATION: KEEP 'FoT Hydrogen peroxide above75ᵗʰ percentile', DROP 'Wet bulb temperature'
#     Reason: Higher target correlation (0.431 vs 0.510)
#
# ----------------------------------------------------------------------
#
#  Saved: weather_feature_selection_recommendations.csv

# %% [markdown]
# ## 12. Summary
#
# **Analysis Completed:**
# -  Identified weather variables (excluded demographics, livestock, irrelevant weather)
# -  Descriptive statistics
# -  Inter-feature correlation matrix (heatmap without annotations)
# -  High correlation pairs identification (|r| > 0.85)
# -  Hierarchical clustering (dendrogram)
# -  Feature-target correlations
# -  Bivariate scatter plots (top 9 features)
# -  Multicollinearity detection (VIF)
# -  Decision recommendations
#
# **Output Files:**
# All visualizations and tables saved to: `data_cvd/outputs/feature_analysis/`
#
# **Next Steps:**
# 1. Review recommendations and make final decisions
# 2. Combine decisions from both notebooks (demographics + weather)
# 3. Create final reduced dataset with selected features only
# 4. Begin machine learning modeling

# %%
# List all generated files for weather analysis
print("=" * 70)
print("OUTPUT FILES GENERATED (WEATHER ANALYSIS)")
print("=" * 70)
print(f"\nDirectory: {output_dir}\n")

weather_files = sorted([f for f in output_dir.glob('weather_*')])
for file in weather_files:
    size_kb = file.stat().st_size / 1024
    print(f"   {file.name} ({size_kb:.1f} KB)")

print(f"\nTotal weather analysis files: {len(weather_files)}")

# Show all files in directory
all_files = sorted(output_dir.glob('*'))
print(f"\nTotal files in directory (demographics + weather): {len(all_files)}")
# Out:
# ======================================================================
# OUTPUT FILES GENERATED (WEATHER ANALYSIS)
# ======================================================================
#
# Directory: ../data_cvd/outputs/feature_analysis
#
#    weather_correlation_matrix.png (813.1 KB)
#    weather_dendrogram.png (506.9 KB)
#    weather_feature_decision_metrics.csv (4.1 KB)
#    weather_feature_selection_recommendations.csv (5.2 KB)
#    weather_high_correlation_pairs.csv (2.3 KB)
#    weather_target_correlation_barplot.png (562.8 KB)
#    weather_target_correlations.csv (2.4 KB)
#    weather_top_features_scatter_plots.png (5321.6 KB)
#    weather_vif_analysis.csv (2.3 KB)
#    weather_vif_barplot.png (580.8 KB)
#
# Total weather analysis files: 10
#
# Total files in directory (demographics + weather): 20
