# %%
import pandas as pd
import requests

# %%
def fetch_and_merge_acs_variable(variable_code, variable_name, year, api_key):
    """
    Fetches an ACS variable from the Census API and merges it with the preprocessed DataFrame.
    
    Parameters:
    variable_code (str): ACS variable code to fetch (e.g., 'B19083_001E' for Gini Index).
    variable_name (str): Descriptive name for the variable (e.g., 'Gini_Index').
    year (int): Year of the ACS data (e.g., 2011).
    api_key (str): API key for accessing the Census API.
    
    Returns:
    pd.DataFrame: Final merged DataFrame with the ACS variable added.
    """
    # Paths for input and output
    preprocessed_path = f'../data/processed/preprocessed_fips_life_expectancy/preprocessed_life_fips_{year}.csv'
    output_path = f'../data/processed/final_dataset/dataset_with_{variable_name}_{year}.csv'
    
    # Load preprocessed life expectancy and FIPS DataFrame
    print(f"Loading preprocessed data for {year}...")
    preprocessed_df = pd.read_csv(preprocessed_path)
    
    # API Endpoint and Parameters
    print(f"Fetching {variable_name} ({variable_code}) from the Census API for {year}...")
    acs_endpoint = f'https://api.census.gov/data/{year}/acs/acs5'
    params = {
        'get': variable_code,
        'for': 'county:*',  # All counties
        'in': 'state:*',    # All states
        'key': api_key      # Authentication
    }
    
    # Make the GET request
    response = requests.get(acs_endpoint, params=params)
    if response.status_code != 200:
        raise Exception(f"Failed to fetch {variable_name}. Status code: {response.status_code}")
    
    # Parse the API Response
    print(f"Processing {variable_name} data...")
    acs_data = response.json()
    acs_df = pd.DataFrame(columns=acs_data[0], data=acs_data[1:])
    acs_df = acs_df.rename(columns={
        variable_code: variable_name,
        'state': 'State_FIPS',
        'county': 'County_FIPS'
    })

    # Ensure FIPS codes are formatted as strings in preprocessed_df
    preprocessed_df['State_FIPS'] = preprocessed_df['State_FIPS'].astype(str).str.zfill(2)
    preprocessed_df['County_FIPS'] = preprocessed_df['County_FIPS'].astype(str).str.zfill(3)
        
    # str.zfill() ensures that the State_FIPS and County_FIPS columns are properly formatted with leading zeros
    acs_df['State_FIPS'] = acs_df['State_FIPS'].str.zfill(2)
    acs_df['County_FIPS'] = acs_df['County_FIPS'].str.zfill(3)
    acs_df[variable_name] = pd.to_numeric(acs_df[variable_name], errors='coerce')
    
    # Merge ACS Data with Preprocessed Data
    print(f"Merging {variable_name} with preprocessed life expectancy data...")
    final_df = pd.merge(
        preprocessed_df,
        acs_df[['State_FIPS', 'County_FIPS', variable_name]],
        on=['State_FIPS', 'County_FIPS'],
        how='left'
    )
    
    # Save the Merged Dataset
    print(f"Saving final dataset with {variable_name} to {output_path}...")
    final_df.to_csv(output_path, index=False)
    
    print(f"Task completed. Final dataset saved: {output_path}")
    return final_df

# %% [markdown]
# *** The code below imports all the single-variable features that do not involve doing arithmetic operations on them like summing or finding percentages. ***

# %%
variables = [{'code': 'B19013_001E', 'name': 'median_household_income'},
             {'code': 'B01003_001E', 'name': 'total_population'},
             {'code': 'B19083_001E', 'name': 'gini_index'},
             {'code': 'B25064_001E', 'name': 'median_gross_rent'},
             {'code': 'B25077_001E', 'name': 'median_home_value'},
             {'code': 'B25070_007E', 'name': 'housing_cost_burden'},
             {'code': 'B19301_001E', 'name': 'per_capita_income'}
             ]
for i in range(2010,2020):
    for var in variables:
        final_df = fetch_and_merge_acs_variable(
            variable_code= var['code'],  # Gini Index variable
            variable_name= var['name'],
            year= i,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2010...
# Fetching median_household_income (B19013_001E) from the Census API for 2010...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2010.csv
# Loading preprocessed data for 2010...
# Fetching total_population (B01003_001E) from the Census API for 2010...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2010.csv
# Loading preprocessed data for 2010...
# Fetching gini_index (B19083_001E) from the Census API for 2010...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2010.csv
# Loading preprocessed data for 2010...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2010...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2010.csv
# Loading preprocessed data for 2010...
# Fetching median_home_value (B25077_001E) from the Census API for 2010...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2010.csv
# Loading preprocessed data for 2010...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2010...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2010.csv
# Loading preprocessed data for 2010...
# Fetching per_capita_income (B19301_001E) from the Census API for 2010...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2010.csv
# Loading preprocessed data for 2011...
# Fetching median_household_income (B19013_001E) from the Census API for 2011...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2011.csv
# Loading preprocessed data for 2011...
# Fetching total_population (B01003_001E) from the Census API for 2011...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2011.csv
# Loading preprocessed data for 2011...
# Fetching gini_index (B19083_001E) from the Census API for 2011...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2011.csv
# Loading preprocessed data for 2011...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2011...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2011.csv
# Loading preprocessed data for 2011...
# Fetching median_home_value (B25077_001E) from the Census API for 2011...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2011.csv
# Loading preprocessed data for 2011...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2011...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2011.csv
# Loading preprocessed data for 2011...
# Fetching per_capita_income (B19301_001E) from the Census API for 2011...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2011.csv
# Loading preprocessed data for 2012...
# Fetching median_household_income (B19013_001E) from the Census API for 2012...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2012.csv
# Loading preprocessed data for 2012...
# Fetching total_population (B01003_001E) from the Census API for 2012...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2012.csv
# Loading preprocessed data for 2012...
# Fetching gini_index (B19083_001E) from the Census API for 2012...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2012.csv
# Loading preprocessed data for 2012...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2012...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2012.csv
# Loading preprocessed data for 2012...
# Fetching median_home_value (B25077_001E) from the Census API for 2012...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2012.csv
# Loading preprocessed data for 2012...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2012...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2012.csv
# Loading preprocessed data for 2012...
# Fetching per_capita_income (B19301_001E) from the Census API for 2012...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2012.csv
# Loading preprocessed data for 2013...
# Fetching median_household_income (B19013_001E) from the Census API for 2013...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2013.csv
# Loading preprocessed data for 2013...
# Fetching total_population (B01003_001E) from the Census API for 2013...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2013.csv
# Loading preprocessed data for 2013...
# Fetching gini_index (B19083_001E) from the Census API for 2013...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2013.csv
# Loading preprocessed data for 2013...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2013...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2013.csv
# Loading preprocessed data for 2013...
# Fetching median_home_value (B25077_001E) from the Census API for 2013...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2013.csv
# Loading preprocessed data for 2013...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2013...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2013.csv
# Loading preprocessed data for 2013...
# Fetching per_capita_income (B19301_001E) from the Census API for 2013...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2013.csv
# Loading preprocessed data for 2014...
# Fetching median_household_income (B19013_001E) from the Census API for 2014...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2014.csv
# Loading preprocessed data for 2014...
# Fetching total_population (B01003_001E) from the Census API for 2014...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2014.csv
# Loading preprocessed data for 2014...
# Fetching gini_index (B19083_001E) from the Census API for 2014...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2014.csv
# Loading preprocessed data for 2014...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2014...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2014.csv
# Loading preprocessed data for 2014...
# Fetching median_home_value (B25077_001E) from the Census API for 2014...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2014.csv
# Loading preprocessed data for 2014...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2014...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2014.csv
# Loading preprocessed data for 2014...
# Fetching per_capita_income (B19301_001E) from the Census API for 2014...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2014.csv
# Loading preprocessed data for 2015...
# Fetching median_household_income (B19013_001E) from the Census API for 2015...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2015.csv
# Loading preprocessed data for 2015...
# Fetching total_population (B01003_001E) from the Census API for 2015...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2015.csv
# Loading preprocessed data for 2015...
# Fetching gini_index (B19083_001E) from the Census API for 2015...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2015.csv
# Loading preprocessed data for 2015...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2015...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2015.csv
# Loading preprocessed data for 2015...
# Fetching median_home_value (B25077_001E) from the Census API for 2015...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2015.csv
# Loading preprocessed data for 2015...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2015...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2015.csv
# Loading preprocessed data for 2015...
# Fetching per_capita_income (B19301_001E) from the Census API for 2015...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2015.csv
# Loading preprocessed data for 2016...
# Fetching median_household_income (B19013_001E) from the Census API for 2016...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2016.csv
# Loading preprocessed data for 2016...
# Fetching total_population (B01003_001E) from the Census API for 2016...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2016.csv
# Loading preprocessed data for 2016...
# Fetching gini_index (B19083_001E) from the Census API for 2016...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2016.csv
# Loading preprocessed data for 2016...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2016...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2016.csv
# Loading preprocessed data for 2016...
# Fetching median_home_value (B25077_001E) from the Census API for 2016...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2016.csv
# Loading preprocessed data for 2016...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2016...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2016.csv
# Loading preprocessed data for 2016...
# Fetching per_capita_income (B19301_001E) from the Census API for 2016...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2016.csv
# Loading preprocessed data for 2017...
# Fetching median_household_income (B19013_001E) from the Census API for 2017...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2017.csv
# Loading preprocessed data for 2017...
# Fetching total_population (B01003_001E) from the Census API for 2017...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2017.csv
# Loading preprocessed data for 2017...
# Fetching gini_index (B19083_001E) from the Census API for 2017...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2017.csv
# Loading preprocessed data for 2017...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2017...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2017.csv
# Loading preprocessed data for 2017...
# Fetching median_home_value (B25077_001E) from the Census API for 2017...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2017.csv
# Loading preprocessed data for 2017...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2017...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2017.csv
# Loading preprocessed data for 2017...
# Fetching per_capita_income (B19301_001E) from the Census API for 2017...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2017.csv
# Loading preprocessed data for 2018...
# Fetching median_household_income (B19013_001E) from the Census API for 2018...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2018.csv
# Loading preprocessed data for 2018...
# Fetching total_population (B01003_001E) from the Census API for 2018...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2018.csv
# Loading preprocessed data for 2018...
# Fetching gini_index (B19083_001E) from the Census API for 2018...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2018.csv
# Loading preprocessed data for 2018...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2018...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2018.csv
# Loading preprocessed data for 2018...
# Fetching median_home_value (B25077_001E) from the Census API for 2018...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2018.csv
# Loading preprocessed data for 2018...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2018...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2018.csv
# Loading preprocessed data for 2018...
# Fetching per_capita_income (B19301_001E) from the Census API for 2018...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2018.csv
# Loading preprocessed data for 2019...
# Fetching median_household_income (B19013_001E) from the Census API for 2019...
# Processing median_household_income data...
# Merging median_household_income with preprocessed life expectancy data...
# Saving final dataset with median_household_income to ../data/processed/final_dataset/dataset_with_median_household_income_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_household_income_2019.csv
# Loading preprocessed data for 2019...
# Fetching total_population (B01003_001E) from the Census API for 2019...
# Processing total_population data...
# Merging total_population with preprocessed life expectancy data...
# Saving final dataset with total_population to ../data/processed/final_dataset/dataset_with_total_population_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_2019.csv
# Loading preprocessed data for 2019...
# Fetching gini_index (B19083_001E) from the Census API for 2019...
# Processing gini_index data...
# Merging gini_index with preprocessed life expectancy data...
# Saving final dataset with gini_index to ../data/processed/final_dataset/dataset_with_gini_index_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_gini_index_2019.csv
# Loading preprocessed data for 2019...
# Fetching median_gross_rent (B25064_001E) from the Census API for 2019...
# Processing median_gross_rent data...
# Merging median_gross_rent with preprocessed life expectancy data...
# Saving final dataset with median_gross_rent to ../data/processed/final_dataset/dataset_with_median_gross_rent_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_gross_rent_2019.csv
# Loading preprocessed data for 2019...
# Fetching median_home_value (B25077_001E) from the Census API for 2019...
# Processing median_home_value data...
# Merging median_home_value with preprocessed life expectancy data...
# Saving final dataset with median_home_value to ../data/processed/final_dataset/dataset_with_median_home_value_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_median_home_value_2019.csv
# Loading preprocessed data for 2019...
# Fetching housing_cost_burden (B25070_007E) from the Census API for 2019...
# Processing housing_cost_burden data...
# Merging housing_cost_burden with preprocessed life expectancy data...
# Saving final dataset with housing_cost_burden to ../data/processed/final_dataset/dataset_with_housing_cost_burden_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_housing_cost_burden_2019.csv
# Loading preprocessed data for 2019...
# Fetching per_capita_income (B19301_001E) from the Census API for 2019...
# Processing per_capita_income data...
# Merging per_capita_income with preprocessed life expectancy data...
# Saving final dataset with per_capita_income to ../data/processed/final_dataset/dataset_with_per_capita_income_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_per_capita_income_2019.csv

# %% [markdown]
# *** The code below are all the variables that are related to educational attainment. They will all be eventually combined into a single "high school and above" category to prevent overfitting.
#
# Visit https://api.census.gov/data/2019/acs/acs5/groups/B15003.html for more information about the variables. ***

# %%
variables = [
    {'code': 'B15003_017E', 'name': 'high_school_grads'},           # High school graduate (regular diploma)
    {'code': 'B15003_018E', 'name': 'ged_or_alternative'},          # GED or alternative credential
    {'code': 'B15003_019E', 'name': 'some_college_less_1_year'},    # Some college, less than 1 year
    {'code': 'B15003_020E', 'name': 'some_college_1_plus_year'},    # Some college, 1 or more years, no degree
    {'code': 'B15003_021E', 'name': 'associates_degree'},           # Associate's degree
    {'code': 'B15003_022E', 'name': 'bachelors_degree'},            # Bachelor's degree
    {'code': 'B15003_023E', 'name': 'masters_degree'},              # Master's degree
    {'code': 'B15003_024E', 'name': 'professional_degree'},         # Professional school degree
    {'code': 'B15003_025E', 'name': 'doctorate_degree'},            # Doctorate degree
    {'code': 'B15003_001E', 'name': 'population_aged_25_plus'}      # Total population aged 25 and over
]
for year in range(2012, 2020):
    for var in variables:
        fetch_and_merge_acs_variable(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2012...
# Fetching high_school_grads (B15003_017E) from the Census API for 2012...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2012.csv
# Loading preprocessed data for 2012...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2012...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2012.csv
# Loading preprocessed data for 2012...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2012...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2012.csv
# Loading preprocessed data for 2012...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2012...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2012.csv
# Loading preprocessed data for 2012...
# Fetching associates_degree (B15003_021E) from the Census API for 2012...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2012.csv
# Loading preprocessed data for 2012...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2012...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2012.csv
# Loading preprocessed data for 2012...
# Fetching masters_degree (B15003_023E) from the Census API for 2012...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2012.csv
# Loading preprocessed data for 2012...
# Fetching professional_degree (B15003_024E) from the Census API for 2012...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2012.csv
# Loading preprocessed data for 2012...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2012...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2012.csv
# Loading preprocessed data for 2012...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2012...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2012.csv
# Loading preprocessed data for 2013...
# Fetching high_school_grads (B15003_017E) from the Census API for 2013...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2013.csv
# Loading preprocessed data for 2013...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2013...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2013.csv
# Loading preprocessed data for 2013...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2013...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2013.csv
# Loading preprocessed data for 2013...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2013...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2013.csv
# Loading preprocessed data for 2013...
# Fetching associates_degree (B15003_021E) from the Census API for 2013...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2013.csv
# Loading preprocessed data for 2013...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2013...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2013.csv
# Loading preprocessed data for 2013...
# Fetching masters_degree (B15003_023E) from the Census API for 2013...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2013.csv
# Loading preprocessed data for 2013...
# Fetching professional_degree (B15003_024E) from the Census API for 2013...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2013.csv
# Loading preprocessed data for 2013...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2013...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2013.csv
# Loading preprocessed data for 2013...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2013...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2013.csv
# Loading preprocessed data for 2014...
# Fetching high_school_grads (B15003_017E) from the Census API for 2014...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2014.csv
# Loading preprocessed data for 2014...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2014...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2014.csv
# Loading preprocessed data for 2014...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2014...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2014.csv
# Loading preprocessed data for 2014...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2014...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2014.csv
# Loading preprocessed data for 2014...
# Fetching associates_degree (B15003_021E) from the Census API for 2014...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2014.csv
# Loading preprocessed data for 2014...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2014...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2014.csv
# Loading preprocessed data for 2014...
# Fetching masters_degree (B15003_023E) from the Census API for 2014...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2014.csv
# Loading preprocessed data for 2014...
# Fetching professional_degree (B15003_024E) from the Census API for 2014...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2014.csv
# Loading preprocessed data for 2014...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2014...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2014.csv
# Loading preprocessed data for 2014...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2014...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2014.csv
# Loading preprocessed data for 2015...
# Fetching high_school_grads (B15003_017E) from the Census API for 2015...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2015.csv
# Loading preprocessed data for 2015...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2015...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2015.csv
# Loading preprocessed data for 2015...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2015...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2015.csv
# Loading preprocessed data for 2015...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2015...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2015.csv
# Loading preprocessed data for 2015...
# Fetching associates_degree (B15003_021E) from the Census API for 2015...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2015.csv
# Loading preprocessed data for 2015...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2015...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2015.csv
# Loading preprocessed data for 2015...
# Fetching masters_degree (B15003_023E) from the Census API for 2015...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2015.csv
# Loading preprocessed data for 2015...
# Fetching professional_degree (B15003_024E) from the Census API for 2015...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2015.csv
# Loading preprocessed data for 2015...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2015...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2015.csv
# Loading preprocessed data for 2015...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2015...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2015.csv
# Loading preprocessed data for 2016...
# Fetching high_school_grads (B15003_017E) from the Census API for 2016...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2016.csv
# Loading preprocessed data for 2016...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2016...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2016.csv
# Loading preprocessed data for 2016...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2016...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2016.csv
# Loading preprocessed data for 2016...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2016...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2016.csv
# Loading preprocessed data for 2016...
# Fetching associates_degree (B15003_021E) from the Census API for 2016...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2016.csv
# Loading preprocessed data for 2016...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2016...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2016.csv
# Loading preprocessed data for 2016...
# Fetching masters_degree (B15003_023E) from the Census API for 2016...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2016.csv
# Loading preprocessed data for 2016...
# Fetching professional_degree (B15003_024E) from the Census API for 2016...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2016.csv
# Loading preprocessed data for 2016...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2016...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2016.csv
# Loading preprocessed data for 2016...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2016...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2016.csv
# Loading preprocessed data for 2017...
# Fetching high_school_grads (B15003_017E) from the Census API for 2017...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2017.csv
# Loading preprocessed data for 2017...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2017...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2017.csv
# Loading preprocessed data for 2017...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2017...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2017.csv
# Loading preprocessed data for 2017...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2017...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2017.csv
# Loading preprocessed data for 2017...
# Fetching associates_degree (B15003_021E) from the Census API for 2017...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2017.csv
# Loading preprocessed data for 2017...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2017...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2017.csv
# Loading preprocessed data for 2017...
# Fetching masters_degree (B15003_023E) from the Census API for 2017...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2017.csv
# Loading preprocessed data for 2017...
# Fetching professional_degree (B15003_024E) from the Census API for 2017...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2017.csv
# Loading preprocessed data for 2017...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2017...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2017.csv
# Loading preprocessed data for 2017...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2017...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2017.csv
# Loading preprocessed data for 2018...
# Fetching high_school_grads (B15003_017E) from the Census API for 2018...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2018.csv
# Loading preprocessed data for 2018...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2018...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2018.csv
# Loading preprocessed data for 2018...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2018...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2018.csv
# Loading preprocessed data for 2018...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2018...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2018.csv
# Loading preprocessed data for 2018...
# Fetching associates_degree (B15003_021E) from the Census API for 2018...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2018.csv
# Loading preprocessed data for 2018...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2018...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2018.csv
# Loading preprocessed data for 2018...
# Fetching masters_degree (B15003_023E) from the Census API for 2018...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2018.csv
# Loading preprocessed data for 2018...
# Fetching professional_degree (B15003_024E) from the Census API for 2018...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2018.csv
# Loading preprocessed data for 2018...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2018...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2018.csv
# Loading preprocessed data for 2018...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2018...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2018.csv
# Loading preprocessed data for 2019...
# Fetching high_school_grads (B15003_017E) from the Census API for 2019...
# Processing high_school_grads data...
# Merging high_school_grads with preprocessed life expectancy data...
# Saving final dataset with high_school_grads to ../data/processed/final_dataset/dataset_with_high_school_grads_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_grads_2019.csv
# Loading preprocessed data for 2019...
# Fetching ged_or_alternative (B15003_018E) from the Census API for 2019...
# Processing ged_or_alternative data...
# Merging ged_or_alternative with preprocessed life expectancy data...
# Saving final dataset with ged_or_alternative to ../data/processed/final_dataset/dataset_with_ged_or_alternative_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_ged_or_alternative_2019.csv
# Loading preprocessed data for 2019...
# Fetching some_college_less_1_year (B15003_019E) from the Census API for 2019...
# Processing some_college_less_1_year data...
# Merging some_college_less_1_year with preprocessed life expectancy data...
# Saving final dataset with some_college_less_1_year to ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_less_1_year_2019.csv
# Loading preprocessed data for 2019...
# Fetching some_college_1_plus_year (B15003_020E) from the Census API for 2019...
# Processing some_college_1_plus_year data...
# Merging some_college_1_plus_year with preprocessed life expectancy data...
# Saving final dataset with some_college_1_plus_year to ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_some_college_1_plus_year_2019.csv
# Loading preprocessed data for 2019...
# Fetching associates_degree (B15003_021E) from the Census API for 2019...
# Processing associates_degree data...
# Merging associates_degree with preprocessed life expectancy data...
# Saving final dataset with associates_degree to ../data/processed/final_dataset/dataset_with_associates_degree_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_associates_degree_2019.csv
# Loading preprocessed data for 2019...
# Fetching bachelors_degree (B15003_022E) from the Census API for 2019...
# Processing bachelors_degree data...
# Merging bachelors_degree with preprocessed life expectancy data...
# Saving final dataset with bachelors_degree to ../data/processed/final_dataset/dataset_with_bachelors_degree_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_bachelors_degree_2019.csv
# Loading preprocessed data for 2019...
# Fetching masters_degree (B15003_023E) from the Census API for 2019...
# Processing masters_degree data...
# Merging masters_degree with preprocessed life expectancy data...
# Saving final dataset with masters_degree to ../data/processed/final_dataset/dataset_with_masters_degree_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_masters_degree_2019.csv
# Loading preprocessed data for 2019...
# Fetching professional_degree (B15003_024E) from the Census API for 2019...
# Processing professional_degree data...
# Merging professional_degree with preprocessed life expectancy data...
# Saving final dataset with professional_degree to ../data/processed/final_dataset/dataset_with_professional_degree_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_professional_degree_2019.csv
# Loading preprocessed data for 2019...
# Fetching doctorate_degree (B15003_025E) from the Census API for 2019...
# Processing doctorate_degree data...
# Merging doctorate_degree with preprocessed life expectancy data...
# Saving final dataset with doctorate_degree to ../data/processed/final_dataset/dataset_with_doctorate_degree_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_doctorate_degree_2019.csv
# Loading preprocessed data for 2019...
# Fetching population_aged_25_plus (B15003_001E) from the Census API for 2019...
# Processing population_aged_25_plus data...
# Merging population_aged_25_plus with preprocessed life expectancy data...
# Saving final dataset with population_aged_25_plus to ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_population_aged_25_plus_2019.csv

# %% [markdown]
# *** Now the variables that are related to race. Check https://api.census.gov/data/2015/acs/acs5/groups/B02001.html for more information. ***

# %%
variables = [
    {'code': 'B02001_001E', 'name': 'total_population_race'},           
    {'code': 'B02001_003E', 'name': 'black_population'},         
    {'code': 'B02001_002E', 'name': 'white_population'},   
    {'code': 'B02001_002E', 'name': 'asian_population'},    
    {'code': 'B02001_004E', 'name': 'native_american_population'}       
]
for year in range(2010, 2020):
    for var in variables:
        fetch_and_merge_acs_variable(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2010...
# Fetching total_population_race (B02001_001E) from the Census API for 2010...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2010.csv
# Loading preprocessed data for 2010...
# Fetching black_population (B02001_003E) from the Census API for 2010...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2010.csv
# Loading preprocessed data for 2010...
# Fetching white_population (B02001_002E) from the Census API for 2010...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2010.csv
# Loading preprocessed data for 2010...
# Fetching asian_population (B02001_002E) from the Census API for 2010...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2010.csv
# Loading preprocessed data for 2010...
# Fetching native_american_population (B02001_004E) from the Census API for 2010...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2010.csv
# Loading preprocessed data for 2011...
# Fetching total_population_race (B02001_001E) from the Census API for 2011...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2011.csv
# Loading preprocessed data for 2011...
# Fetching black_population (B02001_003E) from the Census API for 2011...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2011.csv
# Loading preprocessed data for 2011...
# Fetching white_population (B02001_002E) from the Census API for 2011...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2011.csv
# Loading preprocessed data for 2011...
# Fetching asian_population (B02001_002E) from the Census API for 2011...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2011.csv
# Loading preprocessed data for 2011...
# Fetching native_american_population (B02001_004E) from the Census API for 2011...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2011.csv
# Loading preprocessed data for 2012...
# Fetching total_population_race (B02001_001E) from the Census API for 2012...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2012.csv
# Loading preprocessed data for 2012...
# Fetching black_population (B02001_003E) from the Census API for 2012...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2012.csv
# Loading preprocessed data for 2012...
# Fetching white_population (B02001_002E) from the Census API for 2012...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2012.csv
# Loading preprocessed data for 2012...
# Fetching asian_population (B02001_002E) from the Census API for 2012...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2012.csv
# Loading preprocessed data for 2012...
# Fetching native_american_population (B02001_004E) from the Census API for 2012...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2012.csv
# Loading preprocessed data for 2013...
# Fetching total_population_race (B02001_001E) from the Census API for 2013...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2013.csv
# Loading preprocessed data for 2013...
# Fetching black_population (B02001_003E) from the Census API for 2013...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2013.csv
# Loading preprocessed data for 2013...
# Fetching white_population (B02001_002E) from the Census API for 2013...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2013.csv
# Loading preprocessed data for 2013...
# Fetching asian_population (B02001_002E) from the Census API for 2013...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2013.csv
# Loading preprocessed data for 2013...
# Fetching native_american_population (B02001_004E) from the Census API for 2013...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2013.csv
# Loading preprocessed data for 2014...
# Fetching total_population_race (B02001_001E) from the Census API for 2014...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2014.csv
# Loading preprocessed data for 2014...
# Fetching black_population (B02001_003E) from the Census API for 2014...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2014.csv
# Loading preprocessed data for 2014...
# Fetching white_population (B02001_002E) from the Census API for 2014...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2014.csv
# Loading preprocessed data for 2014...
# Fetching asian_population (B02001_002E) from the Census API for 2014...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2014.csv
# Loading preprocessed data for 2014...
# Fetching native_american_population (B02001_004E) from the Census API for 2014...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2014.csv
# Loading preprocessed data for 2015...
# Fetching total_population_race (B02001_001E) from the Census API for 2015...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2015.csv
# Loading preprocessed data for 2015...
# Fetching black_population (B02001_003E) from the Census API for 2015...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2015.csv
# Loading preprocessed data for 2015...
# Fetching white_population (B02001_002E) from the Census API for 2015...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2015.csv
# Loading preprocessed data for 2015...
# Fetching asian_population (B02001_002E) from the Census API for 2015...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2015.csv
# Loading preprocessed data for 2015...
# Fetching native_american_population (B02001_004E) from the Census API for 2015...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2015.csv
# Loading preprocessed data for 2016...
# Fetching total_population_race (B02001_001E) from the Census API for 2016...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2016.csv
# Loading preprocessed data for 2016...
# Fetching black_population (B02001_003E) from the Census API for 2016...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2016.csv
# Loading preprocessed data for 2016...
# Fetching white_population (B02001_002E) from the Census API for 2016...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2016.csv
# Loading preprocessed data for 2016...
# Fetching asian_population (B02001_002E) from the Census API for 2016...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2016.csv
# Loading preprocessed data for 2016...
# Fetching native_american_population (B02001_004E) from the Census API for 2016...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2016.csv
# Loading preprocessed data for 2017...
# Fetching total_population_race (B02001_001E) from the Census API for 2017...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2017.csv
# Loading preprocessed data for 2017...
# Fetching black_population (B02001_003E) from the Census API for 2017...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2017.csv
# Loading preprocessed data for 2017...
# Fetching white_population (B02001_002E) from the Census API for 2017...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2017.csv
# Loading preprocessed data for 2017...
# Fetching asian_population (B02001_002E) from the Census API for 2017...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2017.csv
# Loading preprocessed data for 2017...
# Fetching native_american_population (B02001_004E) from the Census API for 2017...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2017.csv
# Loading preprocessed data for 2018...
# Fetching total_population_race (B02001_001E) from the Census API for 2018...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2018.csv
# Loading preprocessed data for 2018...
# Fetching black_population (B02001_003E) from the Census API for 2018...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2018.csv
# Loading preprocessed data for 2018...
# Fetching white_population (B02001_002E) from the Census API for 2018...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2018.csv
# Loading preprocessed data for 2018...
# Fetching asian_population (B02001_002E) from the Census API for 2018...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2018.csv
# Loading preprocessed data for 2018...
# Fetching native_american_population (B02001_004E) from the Census API for 2018...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2018.csv
# Loading preprocessed data for 2019...
# Fetching total_population_race (B02001_001E) from the Census API for 2019...
# Processing total_population_race data...
# Merging total_population_race with preprocessed life expectancy data...
# Saving final dataset with total_population_race to ../data/processed/final_dataset/dataset_with_total_population_race_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_race_2019.csv
# Loading preprocessed data for 2019...
# Fetching black_population (B02001_003E) from the Census API for 2019...
# Processing black_population data...
# Merging black_population with preprocessed life expectancy data...
# Saving final dataset with black_population to ../data/processed/final_dataset/dataset_with_black_population_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_black_population_2019.csv
# Loading preprocessed data for 2019...
# Fetching white_population (B02001_002E) from the Census API for 2019...
# Processing white_population data...
# Merging white_population with preprocessed life expectancy data...
# Saving final dataset with white_population to ../data/processed/final_dataset/dataset_with_white_population_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_white_population_2019.csv
# Loading preprocessed data for 2019...
# Fetching asian_population (B02001_002E) from the Census API for 2019...
# Processing asian_population data...
# Merging asian_population with preprocessed life expectancy data...
# Saving final dataset with asian_population to ../data/processed/final_dataset/dataset_with_asian_population_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_asian_population_2019.csv
# Loading preprocessed data for 2019...
# Fetching native_american_population (B02001_004E) from the Census API for 2019...
# Processing native_american_population data...
# Merging native_american_population with preprocessed life expectancy data...
# Saving final dataset with native_american_population to ../data/processed/final_dataset/dataset_with_native_american_population_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_native_american_population_2019.csv

# %% [markdown]
# *** Importing the variables relevant for poverty rate. Check https://api.census.gov/data/2019/acs/acs5/groups/B17001.html for more information. ***

# %%
variables = [
    {'code': 'B17001_002E', 'name': 'people_below_poverty'},           
    {'code': 'B17001_001E', 'name': 'total_population_for_poverty'}          
    ]

for year in range(2010, 2020):
    for var in variables:
        fetch_and_merge_acs_variable(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2010...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2010...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2010.csv
# Loading preprocessed data for 2010...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2010...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2010.csv
# Loading preprocessed data for 2011...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2011...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2011.csv
# Loading preprocessed data for 2011...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2011...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2011.csv
# Loading preprocessed data for 2012...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2012...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2012.csv
# Loading preprocessed data for 2012...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2012...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2012.csv
# Loading preprocessed data for 2013...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2013...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2013.csv
# Loading preprocessed data for 2013...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2013...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2013.csv
# Loading preprocessed data for 2014...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2014...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2014.csv
# Loading preprocessed data for 2014...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2014...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2014.csv
# Loading preprocessed data for 2015...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2015...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2015.csv
# Loading preprocessed data for 2015...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2015...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2015.csv
# Loading preprocessed data for 2016...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2016...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2016.csv
# Loading preprocessed data for 2016...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2016...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2016.csv
# Loading preprocessed data for 2017...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2017...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2017.csv
# Loading preprocessed data for 2017...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2017...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2017.csv
# Loading preprocessed data for 2018...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2018...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2018.csv
# Loading preprocessed data for 2018...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2018...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2018.csv
# Loading preprocessed data for 2019...
# Fetching people_below_poverty (B17001_002E) from the Census API for 2019...
# Processing people_below_poverty data...
# Merging people_below_poverty with preprocessed life expectancy data...
# Saving final dataset with people_below_poverty to ../data/processed/final_dataset/dataset_with_people_below_poverty_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_people_below_poverty_2019.csv
# Loading preprocessed data for 2019...
# Fetching total_population_for_poverty (B17001_001E) from the Census API for 2019...
# Processing total_population_for_poverty data...
# Merging total_population_for_poverty with preprocessed life expectancy data...
# Saving final dataset with total_population_for_poverty to ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_total_population_for_poverty_2019.csv

# %% [markdown]
# *** Importing the variables that use summary tables from the ACS. Notice that all these variables have the letter "S" in front of them. Rewriting the funtion again with a different ACS endpoint to accomodate for this change. ***

# %%
def fetch_and_merge_acs_variable_summary(variable_code, variable_name, year, api_key):
    """
    Fetches an ACS variable from the Census API and merges it with the preprocessed DataFrame.
    
    Parameters:
    variable_code (str): ACS variable code to fetch (e.g., 'B19083_001E' for Gini Index).
    variable_name (str): Descriptive name for the variable (e.g., 'Gini_Index').
    year (int): Year of the ACS data (e.g., 2011).
    api_key (str): API key for accessing the Census API.
    
    Returns:
    pd.DataFrame: Final merged DataFrame with the ACS variable added.
    """
    # Paths for input and output
    preprocessed_path = f'../data/processed/preprocessed_fips_life_expectancy/preprocessed_life_fips_{year}.csv'
    output_path = f'../data/processed/final_dataset/dataset_with_{variable_name}_{year}.csv'
    
    # Load preprocessed life expectancy and FIPS DataFrame
    print(f"Loading preprocessed data for {year}...")
    preprocessed_df = pd.read_csv(preprocessed_path)
    
    # API Endpoint and Parameters
    print(f"Fetching {variable_name} ({variable_code}) from the Census API for {year}...")
    acs_endpoint = f'https://api.census.gov/data/{year}/acs/acs5/subject'
    params = {
        'get': variable_code,
        'for': 'county:*',  # All counties
        'in': 'state:*',    # All states
        'key': api_key      # Authentication
    }
    
    # Make the GET request
    response = requests.get(acs_endpoint, params=params)
    if response.status_code != 200:
        raise Exception(f"Failed to fetch {variable_name}. Status code: {response.status_code}")
    
    # Parse the API Response
    print(f"Processing {variable_name} data...")
    acs_data = response.json()
    acs_df = pd.DataFrame(columns=acs_data[0], data=acs_data[1:])
    acs_df = acs_df.rename(columns={
        variable_code: variable_name,
        'state': 'State_FIPS',
        'county': 'County_FIPS'
    })

    # Ensure FIPS codes are formatted as strings in preprocessed_df
    preprocessed_df['State_FIPS'] = preprocessed_df['State_FIPS'].astype(str).str.zfill(2)
    preprocessed_df['County_FIPS'] = preprocessed_df['County_FIPS'].astype(str).str.zfill(3)
        
    # str.zfill() ensures that the State_FIPS and County_FIPS columns are properly formatted with leading zeros
    acs_df['State_FIPS'] = acs_df['State_FIPS'].str.zfill(2)
    acs_df['County_FIPS'] = acs_df['County_FIPS'].str.zfill(3)
    acs_df[variable_name] = pd.to_numeric(acs_df[variable_name], errors='coerce')
    
    # Merge ACS Data with Preprocessed Data
    print(f"Merging {variable_name} with preprocessed life expectancy data...")
    final_df = pd.merge(
        preprocessed_df,
        acs_df[['State_FIPS', 'County_FIPS', variable_name]],
        on=['State_FIPS', 'County_FIPS'],
        how='left'
    )
    
    # Save the Merged Dataset
    print(f"Saving final dataset with {variable_name} to {output_path}...")
    final_df.to_csv(output_path, index=False)
    
    print(f"Task completed. Final dataset saved: {output_path}")
    return final_df

# %%
variables = [
    {'code': 'S1701_C03_001E', 'name': 'poverty_rate'},
    {'code': 'S2701_C03_001E', 'name': 'health_insurance_rate'}
    ]

#{'code': 'S1701_C03_001E', 'name': 'poverty_rate'},

for year in range(2012, 2020):
    for var in variables:
        fetch_and_merge_acs_variable_summary(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2012...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2012...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2012.csv
# Loading preprocessed data for 2012...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2012...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2012.csv
# Loading preprocessed data for 2013...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2013...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2013.csv
# Loading preprocessed data for 2013...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2013...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2013.csv
# Loading preprocessed data for 2014...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2014...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2014.csv
# Loading preprocessed data for 2014...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2014...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2014.csv
# Loading preprocessed data for 2015...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2015...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2015.csv
# Loading preprocessed data for 2015...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2015...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2015.csv
# Loading preprocessed data for 2016...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2016...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2016.csv
# Loading preprocessed data for 2016...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2016...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2016.csv
# Loading preprocessed data for 2017...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2017...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2017.csv
# Loading preprocessed data for 2017...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2017...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2017.csv
# Loading preprocessed data for 2018...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2018...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2018.csv
# Loading preprocessed data for 2018...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2018...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2018.csv
# Loading preprocessed data for 2019...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2019...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2019.csv
# Loading preprocessed data for 2019...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2019...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2019.csv

# %%
variables = [
    {'code': 'S2301_C04_001E', 'name': 'unemployment_rate'},
    {'code': 'S1501_C02_015E', 'name': 'high_school_and_above_percentage'}
    ]

#{'code': 'S1701_C03_001E', 'name': 'poverty_rate'},
#{'code': 'S2701_C03_001E', 'name': 'health_insurance_rate'},

for year in range(2010, 2020):
    for var in variables:
        fetch_and_merge_acs_variable_summary(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2010...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2010...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2010.csv
# Loading preprocessed data for 2010...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2010...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2010.csv
# Loading preprocessed data for 2011...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2011...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2011.csv
# Loading preprocessed data for 2011...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2011...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2011.csv
# Loading preprocessed data for 2012...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2012...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2012.csv
# Loading preprocessed data for 2012...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2012...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2012.csv
# Loading preprocessed data for 2013...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2013...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2013.csv
# Loading preprocessed data for 2013...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2013...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2013.csv
# Loading preprocessed data for 2014...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2014...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2014.csv
# Loading preprocessed data for 2014...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2014...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2014.csv
# Loading preprocessed data for 2015...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2015...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2015.csv
# Loading preprocessed data for 2015...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2015...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2015.csv
# Loading preprocessed data for 2016...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2016...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2016.csv
# Loading preprocessed data for 2016...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2016...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2016.csv
# Loading preprocessed data for 2017...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2017...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2017.csv
# Loading preprocessed data for 2017...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2017...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2017.csv
# Loading preprocessed data for 2018...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2018...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2018.csv
# Loading preprocessed data for 2018...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2018...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2018.csv
# Loading preprocessed data for 2019...
# Fetching unemployment_rate (S2301_C04_001E) from the Census API for 2019...
# Processing unemployment_rate data...
# Merging unemployment_rate with preprocessed life expectancy data...
# Saving final dataset with unemployment_rate to ../data/processed/final_dataset/dataset_with_unemployment_rate_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_unemployment_rate_2019.csv
# Loading preprocessed data for 2019...
# Fetching high_school_and_above_percentage (S1501_C02_015E) from the Census API for 2019...
# Processing high_school_and_above_percentage data...
# Merging high_school_and_above_percentage with preprocessed life expectancy data...
# Saving final dataset with high_school_and_above_percentage to ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_high_school_and_above_percentage_2019.csv

# %%
variables = [
    {'code': 'S1810_C03_001E', 'name': 'disability_rate'}
    ]

for year in range(2012, 2020):
    for var in variables:
        fetch_and_merge_acs_variable_summary(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2012...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2012...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2012.csv
# Loading preprocessed data for 2013...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2013...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2013.csv
# Loading preprocessed data for 2014...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2014...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2014.csv
# Loading preprocessed data for 2015...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2015...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2015.csv
# Loading preprocessed data for 2016...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2016...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2016.csv
# Loading preprocessed data for 2017...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2017...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2017.csv
# Loading preprocessed data for 2018...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2018...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2018.csv
# Loading preprocessed data for 2019...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2019...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2019.csv

# %% [markdown]
# *** Now since we do not have the data for some of the variables for the years 2010 and 2011, we will use the values from the ACS 1-year estimates instead. We can rewrite the function again so that we have a different acs_endpoint, one that directs us to the 1-year estimates. Everything else remains the same.  ***

# %%
def fetch_and_merge_acs_variable_summary1(variable_code, variable_name, year, api_key):
    """
    Fetches an ACS variable from the Census API and merges it with the preprocessed DataFrame.
    
    Parameters:
    variable_code (str): ACS variable code to fetch (e.g., 'B19083_001E' for Gini Index).
    variable_name (str): Descriptive name for the variable (e.g., 'Gini_Index').
    year (int): Year of the ACS data (e.g., 2011).
    api_key (str): API key for accessing the Census API.
    
    Returns:
    pd.DataFrame: Final merged DataFrame with the ACS variable added.
    """
    # Paths for input and output
    preprocessed_path = f'../data/processed/preprocessed_fips_life_expectancy/preprocessed_life_fips_{year}.csv'
    output_path = f'../data/processed/final_dataset/dataset_with_{variable_name}_{year}.csv'
    
    # Load preprocessed life expectancy and FIPS DataFrame
    print(f"Loading preprocessed data for {year}...")
    preprocessed_df = pd.read_csv(preprocessed_path)

    # API Endpoint and Parameters
    print(f"Fetching {variable_name} ({variable_code}) from the Census API for {year}...")
    acs_endpoint = f'https://api.census.gov/data/{year}/acs/acs1/subject'
    params = {
        'get': variable_code,
        'for': 'county:*',  # All counties
        'in': 'state:*',    # All states
        'key': api_key      # Authentication
    }
    
    # Make the GET request
    response = requests.get(acs_endpoint, params=params)
    if response.status_code != 200:
        raise Exception(f"Failed to fetch {variable_name}. Status code: {response.status_code}")
    
    # Parse the API Response
    print(f"Processing {variable_name} data...")
    acs_data = response.json()
    acs_df = pd.DataFrame(columns=acs_data[0], data=acs_data[1:])
    acs_df = acs_df.rename(columns={
        variable_code: variable_name,
        'state': 'State_FIPS',
        'county': 'County_FIPS'
    })

    # Ensure FIPS codes are formatted as strings in preprocessed_df
    preprocessed_df['State_FIPS'] = preprocessed_df['State_FIPS'].astype(str).str.zfill(2)
    preprocessed_df['County_FIPS'] = preprocessed_df['County_FIPS'].astype(str).str.zfill(3)
        
    # str.zfill() ensures that the State_FIPS and County_FIPS columns are properly formatted with leading zeros
    acs_df['State_FIPS'] = acs_df['State_FIPS'].str.zfill(2)
    acs_df['County_FIPS'] = acs_df['County_FIPS'].str.zfill(3)
    acs_df[variable_name] = pd.to_numeric(acs_df[variable_name], errors='coerce')
    
    # Merge ACS Data with Preprocessed Data
    print(f"Merging {variable_name} with preprocessed life expectancy data...")
    final_df = pd.merge(
        preprocessed_df,
        acs_df[['State_FIPS', 'County_FIPS', variable_name]],
        on=['State_FIPS', 'County_FIPS'],
        how='left'
    )
    
    # Save the Merged Dataset
    print(f"Saving final dataset with {variable_name} to {output_path}...")
    final_df.to_csv(output_path, index=False)
    
    print(f"Task completed. Final dataset saved: {output_path}")
    return final_df

# %%
variables = [
    {'code': 'S1810_C03_001E', 'name': 'disability_rate'},
    {'code': 'S1701_C03_001E', 'name': 'poverty_rate'},
    {'code': 'S2701_C03_001E', 'name': 'health_insurance_rate'}
    ]
for year in range(2010, 2012):
    for var in variables:
        fetch_and_merge_acs_variable_summary1(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2010...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2010...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2010.csv
# Loading preprocessed data for 2010...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2010...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2010.csv
# Loading preprocessed data for 2010...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2010...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2010.csv
# Loading preprocessed data for 2011...
# Fetching disability_rate (S1810_C03_001E) from the Census API for 2011...
# Processing disability_rate data...
# Merging disability_rate with preprocessed life expectancy data...
# Saving final dataset with disability_rate to ../data/processed/final_dataset/dataset_with_disability_rate_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_disability_rate_2011.csv
# Loading preprocessed data for 2011...
# Fetching poverty_rate (S1701_C03_001E) from the Census API for 2011...
# Processing poverty_rate data...
# Merging poverty_rate with preprocessed life expectancy data...
# Saving final dataset with poverty_rate to ../data/processed/final_dataset/dataset_with_poverty_rate_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_poverty_rate_2011.csv
# Loading preprocessed data for 2011...
# Fetching health_insurance_rate (S2701_C03_001E) from the Census API for 2011...
# Processing health_insurance_rate data...
# Merging health_insurance_rate with preprocessed life expectancy data...
# Saving final dataset with health_insurance_rate to ../data/processed/final_dataset/dataset_with_health_insurance_rate_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_health_insurance_rate_2011.csv

# %% [markdown]
# *** Now importing age variables. Check https://api.census.gov/data/2019/acs/acs5/subject/groups/S0101.html for more info. ***

# %%
variables = [
    {'code': 'S0101_C02_022E', 'name': 'age_18_and_under_percentage'},
    {'code': 'S0101_C02_024E', 'name': 'age_15_to_44_percentage'},
    {'code': 'S0101_C02_028E', 'name': 'age_60_and_over'}
    ]
for year in range(2010, 2020):
    for var in variables:
        fetch_and_merge_acs_variable_summary(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key='2a58865a16f7670d452bcfcb4a5b767db1ce8973'
        )
# Out:
# Loading preprocessed data for 2010...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2010...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2010.csv
# Loading preprocessed data for 2010...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2010...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2010.csv
# Loading preprocessed data for 2010...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2010...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2010.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2010.csv
# Loading preprocessed data for 2011...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2011...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2011.csv
# Loading preprocessed data for 2011...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2011...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2011.csv
# Loading preprocessed data for 2011...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2011...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2011.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2011.csv
# Loading preprocessed data for 2012...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2012...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2012.csv
# Loading preprocessed data for 2012...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2012...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2012.csv
# Loading preprocessed data for 2012...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2012...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2012.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2012.csv
# Loading preprocessed data for 2013...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2013...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2013.csv
# Loading preprocessed data for 2013...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2013...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2013.csv
# Loading preprocessed data for 2013...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2013...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2013.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2013.csv
# Loading preprocessed data for 2014...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2014...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2014.csv
# Loading preprocessed data for 2014...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2014...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2014.csv
# Loading preprocessed data for 2014...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2014...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2014.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2014.csv
# Loading preprocessed data for 2015...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2015...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2015.csv
# Loading preprocessed data for 2015...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2015...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2015.csv
# Loading preprocessed data for 2015...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2015...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2015.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2015.csv
# Loading preprocessed data for 2016...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2016...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2016.csv
# Loading preprocessed data for 2016...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2016...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2016.csv
# Loading preprocessed data for 2016...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2016...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2016.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2016.csv
# Loading preprocessed data for 2017...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2017...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2017.csv
# Loading preprocessed data for 2017...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2017...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2017.csv
# Loading preprocessed data for 2017...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2017...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2017.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2017.csv
# Loading preprocessed data for 2018...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2018...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2018.csv
# Loading preprocessed data for 2018...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2018...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2018.csv
# Loading preprocessed data for 2018...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2018...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2018.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2018.csv
# Loading preprocessed data for 2019...
# Fetching age_18_and_under_percentage (S0101_C02_022E) from the Census API for 2019...
# Processing age_18_and_under_percentage data...
# Merging age_18_and_under_percentage with preprocessed life expectancy data...
# Saving final dataset with age_18_and_under_percentage to ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_18_and_under_percentage_2019.csv
# Loading preprocessed data for 2019...
# Fetching age_15_to_44_percentage (S0101_C02_024E) from the Census API for 2019...
# Processing age_15_to_44_percentage data...
# Merging age_15_to_44_percentage with preprocessed life expectancy data...
# Saving final dataset with age_15_to_44_percentage to ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_15_to_44_percentage_2019.csv
# Loading preprocessed data for 2019...
# Fetching age_60_and_over (S0101_C02_028E) from the Census API for 2019...
# Processing age_60_and_over data...
# Merging age_60_and_over with preprocessed life expectancy data...
# Saving final dataset with age_60_and_over to ../data/processed/final_dataset/dataset_with_age_60_and_over_2019.csv...
# Task completed. Final dataset saved: ../data/processed/final_dataset/dataset_with_age_60_and_over_2019.csv
