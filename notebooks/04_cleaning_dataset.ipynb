# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/combined_by_year/combined_all_years.csv')

# %%
df.head()
# Out:
#              County           State  State_FIPS  County_FIPS  disability_rate  \
# 0  Abbeville County  South Carolina          45            1             19.7
# 1     Acadia Parish       Louisiana          22            1             17.9
# 2   Accomack County        Virginia          51            1             11.8
# 3        Ada County           Idaho          16            1              9.6
# 4      Adair County            Iowa          19            1             13.7
#
#    white_population  total_population  age_60_and_over  poverty_rate  \
# 0           17759.0           25387.0             14.7          20.8
# 1           48543.0           61611.0             10.9          19.1
# 2           22586.0           33454.0             17.5          20.2
# 3          363070.0          394961.0              9.3          12.2
# 4            7457.0            7628.0             18.6           9.9
#
#    housing_cost_burden  ...  unemployment_rate  median_household_income  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24888 entries, 0 to 24887
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   County                          24888 non-null  object
#  1   State                           24888 non-null  object
#  2   State_FIPS                      24888 non-null  int64
#  3   County_FIPS                     24888 non-null  int64
#  4   disability_rate                 24872 non-null  float64
#  5   white_population                24872 non-null  float64
#  6   total_population                24872 non-null  float64
#  7   age_60_and_over                 24872 non-null  float64
#  8   poverty_rate                    24871 non-null  float64
#  9   housing_cost_burden             24871 non-null  float64
#  10  bachelors_and_above_percentage  24872 non-null  float64
#  11  median_gross_rent               24871 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# County                             0
# State                              0
# State_FIPS                         0
# County_FIPS                        0
# disability_rate                   16
# white_population                  16
# total_population                  16
# age_60_and_over                   16
# poverty_rate                      17
# housing_cost_burden               17
# bachelors_and_above_percentage    16
# median_gross_rent                 17
# age_15_to_44_percentage           16
# gini_index                        17
# native_american_population        16
# less_than_9th_grade_percentage    16
# health_insurance_rate             16
# unemployment_rate                 17
# median_household_income           17
# asian_population                  16
# per_capita_income                 17
# total_population_race             16
# high_school_only_percentage       16
# median_home_value                 16
# black_population                  16
# ...

# %%
# Looking up the rows that have empty values

df[df.isna().any(axis=1)]
# Out:
#                          County         State  State_FIPS  County_FIPS  \
# 6385               Bedford City      Virginia          51          515
# 9496               Bedford City      Virginia          51          515
# 11911            Shannon County  South Dakota          46          113
# 12013             Storey County        Nevada          32           29
# 12208  Wade Hampton Census Area        Alaska           2          270
# 12607              Bedford City      Virginia          51          515
# 15022            Shannon County  South Dakota          46          113
# 15319  Wade Hampton Census Area        Alaska           2          270
# 15718              Bedford City      Virginia          51          515
# 18133            Shannon County  South Dakota          46          113
# 18430  Wade Hampton Census Area        Alaska           2          270
# 18829              Bedford City      Virginia          51          515
# ...

# %%
# Deleting all the rows with empty values and creating a new dataframe 

df_cleaned = df.dropna()

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24870 entries, 0 to 24887
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   County                          24870 non-null  object
#  1   State                           24870 non-null  object
#  2   State_FIPS                      24870 non-null  int64
#  3   County_FIPS                     24870 non-null  int64
#  4   disability_rate                 24870 non-null  float64
#  5   white_population                24870 non-null  float64
#  6   total_population                24870 non-null  float64
#  7   age_60_and_over                 24870 non-null  float64
#  8   poverty_rate                    24870 non-null  float64
#  9   housing_cost_burden             24870 non-null  float64
#  10  bachelors_and_above_percentage  24870 non-null  float64
#  11  median_gross_rent               24870 non-null  float64
# ...

# %%
df_cleaned.isna().sum()
# Out:
# County                            0
# State                             0
# State_FIPS                        0
# County_FIPS                       0
# disability_rate                   0
# white_population                  0
# total_population                  0
# age_60_and_over                   0
# poverty_rate                      0
# housing_cost_burden               0
# bachelors_and_above_percentage    0
# median_gross_rent                 0
# age_15_to_44_percentage           0
# gini_index                        0
# native_american_population        0
# less_than_9th_grade_percentage    0
# health_insurance_rate             0
# unemployment_rate                 0
# median_household_income           0
# asian_population                  0
# per_capita_income                 0
# total_population_race             0
# high_school_only_percentage       0
# median_home_value                 0
# black_population                  0
# age_18_and_under_percentage       0
# ...

# %%
df_cleaned.head()
# Out:
#              County           State  State_FIPS  County_FIPS  disability_rate  \
# 0  Abbeville County  South Carolina          45            1             19.7
# 1     Acadia Parish       Louisiana          22            1             17.9
# 2   Accomack County        Virginia          51            1             11.8
# 3        Ada County           Idaho          16            1              9.6
# 4      Adair County            Iowa          19            1             13.7
#
#    white_population  total_population  age_60_and_over  poverty_rate  \
# 0           17759.0           25387.0             14.7          20.8
# 1           48543.0           61611.0             10.9          19.1
# 2           22586.0           33454.0             17.5          20.2
# 3          363070.0          394961.0              9.3          12.2
# 4            7457.0            7628.0             18.6           9.9
#
#    housing_cost_burden  ...  unemployment_rate  median_household_income  \
# ...

# %%
df[(df == -666666666).any(axis=1)].count()
# Out:
# County                            12
# State                             12
# State_FIPS                        12
# County_FIPS                       12
# disability_rate                   12
# white_population                  12
# total_population                  12
# age_60_and_over                   12
# poverty_rate                      12
# housing_cost_burden               12
# bachelors_and_above_percentage    12
# median_gross_rent                 12
# age_15_to_44_percentage           12
# gini_index                        12
# native_american_population        12
# less_than_9th_grade_percentage    12
# health_insurance_rate             12
# unemployment_rate                 12
# median_household_income           12
# asian_population                  12
# per_capita_income                 12
# total_population_race             12
# high_school_only_percentage       12
# median_home_value                 12
# black_population                  12
# ...

# %%
# Identifying the rows with -666666666

rows = df[(df == -666666666).any(axis=1)]
rows
# Out:
#                County   State  State_FIPS  County_FIPS  disability_rate  \
# 1449   Kalawao County  Hawaii          15            5              6.6
# 4560   Kalawao County  Hawaii          15            5             10.0
# 7671   Kalawao County  Hawaii          15            5             12.3
# 10782  Kalawao County  Hawaii          15            5             12.0
# 13080   Cottle County   Texas          48          101             20.1
# 13893  Kalawao County  Hawaii          15            5             19.5
# 16253  Daggett County    Utah          49            9              9.8
# 17004  Kalawao County  Hawaii          15            5             23.4
# 19551   Eureka County  Nevada          32           11             18.0
# 20115  Kalawao County  Hawaii          15            5             24.3
# 22662   Eureka County  Nevada          32           11             17.2
# 23226  Kalawao County  Hawaii          15            5             24.6
#
# ...

# %%
# Dropping the rows with -666666666 and creating a new dataframe

df_cleaned_final = df_cleaned[(df_cleaned != -666666666).all(axis=1)]

# %%
df_cleaned_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24858 entries, 0 to 24887
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   County                          24858 non-null  object
#  1   State                           24858 non-null  object
#  2   State_FIPS                      24858 non-null  int64
#  3   County_FIPS                     24858 non-null  int64
#  4   disability_rate                 24858 non-null  float64
#  5   white_population                24858 non-null  float64
#  6   total_population                24858 non-null  float64
#  7   age_60_and_over                 24858 non-null  float64
#  8   poverty_rate                    24858 non-null  float64
#  9   housing_cost_burden             24858 non-null  float64
#  10  bachelors_and_above_percentage  24858 non-null  float64
#  11  median_gross_rent               24858 non-null  float64
# ...

# %%
df_cleaned_final[(df_cleaned_final == -666666666).any(axis=1)].count()
# Out:
# County                            0
# State                             0
# State_FIPS                        0
# County_FIPS                       0
# disability_rate                   0
# white_population                  0
# total_population                  0
# age_60_and_over                   0
# poverty_rate                      0
# housing_cost_burden               0
# bachelors_and_above_percentage    0
# median_gross_rent                 0
# age_15_to_44_percentage           0
# gini_index                        0
# native_american_population        0
# less_than_9th_grade_percentage    0
# health_insurance_rate             0
# unemployment_rate                 0
# median_household_income           0
# asian_population                  0
# per_capita_income                 0
# total_population_race             0
# high_school_only_percentage       0
# median_home_value                 0
# black_population                  0
# age_18_and_under_percentage       0
# ...

# %%
output_dir = '../data/cleaned/combined_all_years_cleaned.csv'

# %%
df_cleaned_final.to_csv(output_dir, index=False)
